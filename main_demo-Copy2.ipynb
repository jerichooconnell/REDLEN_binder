# %% [markdown]
# ## Analysis of multiplex Reconstructions
#
# Comparing the CNR in all of the methods of reconstruction as well as the qualitative signal.

# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
from analyze_CBCT3 import *
dir_data = './AuGdI_phantom_recons/'
# Out:
# Populating the interactive namespace from numpy and matplotlib
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# C:\ProgramData\Miniconda3\lib\site-packages\IPython\core\magics\pylab.py:160: UserWarning: pylab import has clobbered these variables: ['indices', 'size', 'i0']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
for energy_bin in range(0,7):
    
    main(str(energy_bin),dir_data)

# %% [markdown]
# ### Fig. 4.
#
# Each image is one axial slice of the CT reconstruction: a) The first K-edge image isolating iodine, b) the second K-edge image isolating Gadoliniumand finally c) the third K-edge image isolating Gold. Subplot d) is the summedreconstruction over all of the energy bins, the circles in the image representthe ROIs taken from the image to generate the CNR, the red circle is the ROIused to define the contrast to noise ratio.

# %%
main_Kedge_subtracted_HU(dir_data)
# Out:
# Energy bin: K-edge SEC5 - SEC4
# CNR of 1% Au vial:  4.389304472133544  +/-  2.79994120289566
# CNR of 5% Au vial:  22.373528464986645  +/-  2.377125965426498
# Energy bin: K-edge SEC3 - SEC2
# CNR of 1% Gd vial:  10.629878679879551  +/-  3.010791216216633
# CNR of 5% Gd vial:  26.45031624513559  +/-  4.233366485142992
# Energy bin: K-edge SEC1 - SEC0
# CNR of 1% I vial:  29.580327724237247  +/-  3.09487495247839
# CNR of 5% I vial:  149.39026381651342  +/-  3.283925142780701

# %% [markdown]
# ### Fig. 5.
#
# a) Shows the CT image for reference. b) Shows reconstructed RGBusing  the  reconstruction  of  all  of  the  energy  bins  with  an  RGB  created  byassigning an gold colormap to Gold, green to Gadolinium and purple to Iodine.All  of  the  K-edge  images  are  scaled  between  0  and  5%  concentration  ofcontrast agents. c) is the composite of the two images.

# %%
plot_composite()

# %% [markdown]
# ### Fig. 6.
#
# The CNR results for the K-edge images as well as the bins used toconstruct the images for comparison. The red line denotes the limit of humanvision at a CNR value of 4.

# %%
# %pylab inline
end_plotCNR(dir_data)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Fig. 7.

# %%
main_Kedge_subtracted_HU_norm(dir_data)
# Out:
# iodine r2 0.9999827068022061
# gadolinium r2 0.9998209176857714
# gold r2 0.9994360173087452

# %%
main()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-131-263240bbee7e> in <module>
# ----> 1 main()
#
# TypeError: main() missing 2 required positional arguments: 'energy_bin' and 'directory'

# %%
gold_dataK, gadolinium_dataK, iodine_dataK = np.load(dir_data + "CNRdata_Kedge_SECmultiplex_corrected2.npy")
gold_data1, gadolinium_data1, iodine_data1 = np.load(dir_data + "CNRdata_1_multiplexslice_corrected2.npy")
gold_data2, gadolinium_data2, iodine_data2 = np.load(dir_data + "CNRdata_2_multiplexslice_corrected2.npy")
gold_data3, gadolinium_data3, iodine_data3 = np.load(dir_data + "CNRdata_3_multiplexslice_corrected2.npy")
gold_data0, gadolinium_data0, iodine_data0 = np.load(dir_data + "CNRdata_0_multiplexslice_corrected2.npy")
gold_data4, gadolinium_data4, iodine_data4 = np.load(dir_data + "CNRdata_4_multiplexslice_corrected2.npy")
gold_data5, gadolinium_data5, iodine_data5 = np.load(dir_data + "CNRdata_5_multiplexslice_corrected2.npy")
gold_data6, gadolinium_data6, iodine_data6 = np.load(dir_data + "CNRdata_6_multiplexslice_corrected2.npy")

# %%
gadolinium_data6
# Out:
# array([15.24303412,  1.56798104,  2.6442656 ,  1.33113841])

# %%
gadolinium_data5
# Out:
# array([16.12196093,  1.42476118,  2.10924542,  1.34355961])

# %%
gadolinium_data4
# Out:
# array([14.79115167,  1.46182051, 10.72925825,  1.41952263])

# %%
gadolinium_data3
# Out:
# array([15.42930836,  1.35582712,  5.92664086,  1.54458818])

# %%
gadolinium_data2
# Out:
# array([20.49800077,  1.53229954,  0.73626972,  1.52303746])

# %%
gadolinium_data1
# Out:
# array([21.3031604 ,  1.55373022,  0.56812945,  1.47851015])

# %%
gadolinium_data0
# Out:
# array([26.42566387,  1.95000606,  0.5512377 ,  1.64262354])

# %%
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.cm as cm

# %matplotlib nbagg

# generate some random data
npoints = 5
x = np.random.randn(npoints)
y = np.random.randn(npoints)

# make the size proportional to the distance from the origin
s = [0.1*np.linalg.norm([a, b]) for a, b in zip(x, y)]
s = [a / max(s) for a in s]  # scale

# set color based on size
c = s
colors = [cm.jet(color) for color in c]  # gets the RGBA values from a float

# create a new figure
plt.figure()
ax = plt.gca()
for a, b, color, size in zip(x, y, colors, s):
    # plot circles using the RGBA colors
    circle = plt.Circle((a, b), size, color=color, fill=False)
    ax.add_artist(circle)

# you may need to adjust the lims based on your data
minxy = 1.5*min(min(x), min(y))
maxxy = 1.5*max(max(x), max(y))
plt.xlim([minxy, maxxy])
plt.ylim([minxy, maxxy])
ax.set_aspect(1.0)  # make aspect ratio square

# plot the scatter plot
plt.scatter(x,y,s=0, c=c, cmap='jet', facecolors='none')
plt.grid()
plt.colorbar()  # this works because of the scatter
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.pylab as plt
import numpy as np

f,a = plt.subplots()
x = np.linspace(1,10,100)
y = np.sin(x)
a.plot(x,y)
pos = []
def onclick(event):
    pos.append([event.xdata,event.ydata])
f.canvas.mpl_connect('button_press_event', onclick)
f.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
%
# Out:
# []

# %%
'''
After running main() method, do the K-edge subtraction
:return:
'''
slice_no = 15
m = 16

i5 = []
gd5 = []
au5 = []

i1 = []
gd1 = []
au1 = []

i0 = []
gd0 = []
au0 = []

radius = 1.593
directory = "./images"
#dir_data = "./data_no_smoothing/"

#for i in range(15,16):
i = 15

#plt.style.use('dark_background')
fig, ax = plt.subplots(nrows=3,ncols=1,figsize=(10,10), dpi=300)

ax[0] = plt.subplot(2, 2, 1)
ax[1] = plt.subplot(2, 2, 2)
ax[2] = plt.subplot(2, 2, 3)


SIZE = 8
width = 0.1
indices = [0] 


for slice_no in range(15):

    img0 = sio.loadmat(dir_data + "binSEC0_multiplex_corrected2.mat")['Reconimg'][:,:,slice_no]
    img1 = sio.loadmat(dir_data + "binSEC1_multiplex_corrected2.mat")['Reconimg'][:,:,slice_no]
    img2 = sio.loadmat(dir_data + "binSEC2_multiplex_corrected2.mat")['Reconimg'][:,:,slice_no]
    img3 = sio.loadmat(dir_data + "binSEC3_multiplex_corrected2.mat")['Reconimg'][:,:,slice_no]
    img4 = sio.loadmat(dir_data + "binSEC4_multiplex_corrected2.mat")['Reconimg'][:,:,slice_no]
    img5 = sio.loadmat(dir_data + "binSEC5_multiplex_corrected2.mat")['Reconimg'][:,:,slice_no]
    img6 = sio.loadmat(dir_data + "binSEC6_multiplex_corrected2.mat")['Reconimg'][:,:,slice_no]
    #import ipdb; ipdb.set_trace() 

    size = np.shape(img0)[0] #same size as all 3 here

    noise_roi = getBackgroundRegion(size)

    img_I = (img2 - img0)
    img_Gd = (img3  - img2)
    img_Au = (img5  - img4)

    noise_roi = getBackgroundRegion(size)
    air_roi = getAirRegion(size)

    number_of_noise_pixels = np.sum(noise_roi)
    number_of_air_pixels = np.sum(air_roi)

    noise_fbp_image = noise_roi * img0
    noise_air_image = air_roi * img0
    background_noise0 = np.sum(noise_fbp_image) / number_of_noise_pixels
    air_noise0 = np.sum(noise_air_image) / number_of_air_pixels
    ct_image0 = 1000 * ((img0 - background_noise0)/(background_noise0 - air_noise0))

    noise_fbp_image = noise_roi * img1
    noise_air_image = air_roi * img1
    background_noise1 = np.sum(noise_fbp_image) / number_of_noise_pixels
    air_noise1 = np.sum(noise_air_image) / number_of_air_pixels
    ct_image1 = 1000 * ((img1  - background_noise1)/(background_noise1 - air_noise1))

    noise_fbp_image = noise_roi * img2
    noise_air_image = air_roi * img2  
    background_noise2 = np.sum(noise_fbp_image) / number_of_noise_pixels
    air_noise2 = np.sum(noise_air_image) / number_of_air_pixels
    ct_image2 = 1000 * ((img2 - background_noise2)/(background_noise2 - air_noise2)) 

    noise_fbp_image = noise_roi * img3
    noise_air_image = air_roi * img3
    background_noise3 = np.sum(noise_fbp_image) / number_of_noise_pixels
    air_noise3 = np.sum(noise_air_image) / number_of_air_pixels
    ct_image3 = 1000 * ((img3 - background_noise3)/(background_noise3 - air_noise3))

    noise_fbp_image = noise_roi * img4
    noise_air_image = air_roi * img4  
    background_noise4 = np.sum(noise_fbp_image) / number_of_noise_pixels
    air_noise4 = np.sum(noise_air_image) / number_of_air_pixels
    ct_image4 = 1000 * ((img4 - background_noise4)/(background_noise4 - air_noise4))

    noise_fbp_image = noise_roi * img5
    noise_air_image = air_roi * img5  
    background_noise5 = np.sum(noise_fbp_image) / number_of_noise_pixels
    air_noise5 = np.sum(noise_air_image) / number_of_air_pixels
    ct_image5 = 1000 * ((img5 - background_noise5)/(background_noise5 - air_noise5))

    noise_fbp_image = noise_roi * img6
    noise_air_image = air_roi * img6  
    background_noise6 = np.sum(noise_fbp_image) / number_of_noise_pixels
    air_noise6 = np.sum(noise_air_image) / number_of_air_pixels
    ct_image6 = 1000 * ((img6 - background_noise6)/(background_noise6 - air_noise6))

    ct_image_I = (ct_image2 - ct_image0) #/(ct_image1 + ct_image0)
    ct_image_Gd = (ct_image3  - ct_image2) #/(ct_image3  + ct_image2)
    ct_image_Au = (ct_image5  - ct_image4) #/(ct_image5  + ct_image4)


    ct_image = np.dstack((ct_image_Gd,ct_image_Au,ct_image_I))
    that3 = np.argmax(ct_image,axis=2)
    that4 = np.argmin(ct_image,axis=2)
    difference = np.std(ct_image,axis=2) # - np.min(ct_image,axis=2)

    gold5_roi = getVialRegion("vial5Au", size)
    gold1_roi = getVialRegion("vial1Au", size)
    gadolinium5_roi = getVialRegion("vial5Gd", size)
    gadolinium1_roi = getVialRegion("vial1Gd", size)
    iodine5_roi = getVialRegion("vial5I", size)
    iodine1_roi = getVialRegion("vial1I", size)
    noise_roi = getBackgroundRegion(size)


    np_Gd = np.sum(gadolinium5_roi)
    np_Au = np.sum(gold5_roi)
    np_I = np.sum(iodine5_roi)

    np_Gd1 = np.sum(gadolinium1_roi)
    np_Au1 = np.sum(gold1_roi)
    np_I1 = np.sum(iodine1_roi)
    np_n = np.sum(noise_roi)

    av_Gd = np.sum(gadolinium5_roi*ct_image_Gd) /np_Gd 
    av_Au = np.sum(gold5_roi*ct_image_Au)       /np_Au
    av_I  = np.sum(iodine5_roi*ct_image_I)      /np_I

    ct_image_I /= av_I
    ct_image_Au /= av_Au
    ct_image_Gd /= av_Gd

    ct_image_I *= 5
    ct_image_Au *= 2
    ct_image_Gd *= 5

    av_Gd = np.sum(gadolinium5_roi*ct_image_Gd) /np_Gd 
    av_Au = np.sum(gold5_roi*ct_image_Au)       /np_Au
    av_I  = np.sum(iodine5_roi*ct_image_I)      /np_I    

    std_Gd = np.std(ct_image_Gd[gadolinium5_roi != 0]) 
    std_Au = np.std(ct_image_Au[gold5_roi != 0])
    std_I  = np.std(ct_image_I[iodine5_roi != 0])   

    av_Gd1 = np.sum(gadolinium1_roi*ct_image_Gd) /np_Gd1 
    av_Au1 = np.sum(gold1_roi*ct_image_Au)       /np_Au1
    av_I1  = np.sum(iodine1_roi*ct_image_I)      /np_I1    

    std_Gd1 = np.std(ct_image_Gd[gadolinium1_roi != 0]) 
    std_Au1 = np.std(ct_image_Au[gold1_roi != 0])
    std_I1  = np.std(ct_image_I[iodine1_roi != 0]) 

    av_Gd0 = np.sum(noise_roi*ct_image_Gd) /np_n 
    av_Au0 = np.sum(noise_roi*ct_image_Au) /np_n
    av_I0  = np.sum(noise_roi*ct_image_I)  /np_n

    std_Gd0 = np.std(ct_image_Gd[noise_roi != 0])
    std_I0 = np.std(ct_image_I[noise_roi != 0])
    std_Au0 = np.std(ct_image_Au[noise_roi != 0]) 
    #import ipdb; ipdb.set_trace()

    indices2 = 0 + (slice_no - 11.5)*0.03
    msize = 6
#     i5.append(av_I)
#     gd5.append(av_Gd)
#     au5.append(av_Au)

#     i1.append(av_I1)
#     gd1.append(av_Gd1)
#     au1.append(av_Au1)

#     i0.append(av_I0)
#     gd0.append(av_Gd0)
#     au0.append(av_Au0)

    ct_image_Au[ct_image_Au < 0] = 0
    ct_image_I[ct_image_I < 0] = 0
    ct_image_Gd[ct_image_Gd < 0] = 0

    ct_image_Au[ct_image_Au > 300] = 300
    ct_image_I[ct_image_I > 300] = 300
    ct_image_Gd[ct_image_Gd > 300] = 300

    cnr_gold1, err_gold1, cnr_gold5, err_gold5 = calculateCNR(ct_image_Au, gold1_roi, gold5_roi, noise_roi)
    print("Energy bin: K-edge SEC5 - SEC4")
    print("CNR of 1% Au vial: ", cnr_gold1, " +/- ", err_gold1)
    print("CNR of 5% Au vial: ", cnr_gold5, " +/- ", err_gold5)

    cnr_gadolinium1, err_gadolinium1, cnr_gadolinium5, err_gadolinium5 = calculateCNR(ct_image_Gd, gadolinium1_roi,
                                                                                  gadolinium5_roi, noise_roi)
    print( "Energy bin: K-edge SEC3 - SEC2")
    print( "CNR of 1% Gd vial: ", cnr_gadolinium1, " +/- ", err_gadolinium1)
    print( "CNR of 5% Gd vial: ", cnr_gadolinium5, " +/- ", err_gadolinium5)

    cnr_iodine1, err_iodine1, cnr_iodine5, err_iodine5 = calculateCNR(ct_image_I, iodine1_roi,
                                                                  iodine5_roi, noise_roi)
    print( "Energy bin: K-edge SEC1 - SEC0")
    print( "CNR of 1% I vial: ", cnr_iodine1, " +/- ", err_iodine1)
    print( "CNR of 5% I vial: ", cnr_iodine5, " +/- ", err_iodine5)
                                                 
    i5.append(cnr_iodine5)
    gd5.append(cnr_gadolinium5)
    au5.append(cnr_gold5)

    i1.append(cnr_iodine1)
    gd1.append(cnr_gadolinium1)
    au1.append(cnr_gold1)

    i0.append(av_I0/std_I0)
    gd0.append(av_Gd0/std_Gd0)
    au0.append(av_Au0/std_Au0)

    ax[0].scatter(5 + indices2, av_I/std_I,marker='_',color='#101010',s=msize)
    indices[0] += 1
    ax[1].scatter(5+ indices2, av_Gd/std_Gd,color='#101010',marker='_',s=msize)
    indices[0] += 1
    ax[2].scatter(5+ indices2, av_Au/std_Au,color='#101010',marker='_',s=msize)
    indices[0] += 1
    indices[0] += 1

    ax[0].scatter(1+ indices2, av_I1/std_I1, color='#101010',marker='_',s=msize)
    indices[0] += 1
    ax[1].scatter(2+ indices2, av_Gd1/std_Gd1, color='#101010',marker='_',s=msize)
    indices[0] += 1
    ax[2].scatter(1+ indices2, av_Au1/std_Au1, color='#101010',marker='_',s=msize)
    indices[0] += 1
    indices[0] += 1




arr_img = plt.imread('5%au.png', format='png')

imagebox = OffsetImage(arr_img, zoom=0.1)
imagebox.image.axes = ax[2]
offset = 1.9

ab = AnnotationBbox(imagebox, (5,0),
        xybox=(0, -7),
        xycoords=("data", "axes fraction"),
        boxcoords="offset points",
        box_alignment=(.5, offset),
        bboxprops={"edgecolor" : "k",
        "facecolor":'k'})

ax[2].add_artist(ab)

arr_img = plt.imread('1%au.png', format='png')

imagebox = OffsetImage(arr_img, zoom=0.1)
imagebox.image.axes = ax[2]

ab = AnnotationBbox(imagebox, (1,0),
        xybox=(0, -7),
        xycoords=("data", "axes fraction"),
        boxcoords="offset points",
        box_alignment=(.5, offset),
        bboxprops={"edgecolor" : "k",
        "facecolor":'k'})

ax[2].add_artist(ab)

arr_img = plt.imread('0%au.png', format='png')

imagebox = OffsetImage(arr_img, zoom=0.1)
imagebox.image.axes = ax[2]

ab = AnnotationBbox(imagebox, (0,0),
        xybox=(0, -7),
        xycoords=("data", "axes fraction"),
        boxcoords="offset points",
        box_alignment=(.5, offset),
        bboxprops={"edgecolor" : "k",
        "facecolor":'k'})

ax[2].add_artist(ab)

arr_img = plt.imread('5%i.png', format='png')

imagebox = OffsetImage(arr_img, zoom=0.1)
imagebox.image.axes = ax[0]

ab = AnnotationBbox(imagebox, (5,0),
        xybox=(0, -7),
        xycoords=("data", "axes fraction"),
        boxcoords="offset points",
        box_alignment=(.5, offset),
        bboxprops={"edgecolor" : "k",
        "facecolor":'k'})

ax[0].add_artist(ab)

arr_img = plt.imread('1%i.png', format='png')

imagebox = OffsetImage(arr_img, zoom=0.1)
imagebox.image.axes = ax[0]

ab = AnnotationBbox(imagebox, (1,0),
        xybox=(0, -7),
        xycoords=("data", "axes fraction"),
        boxcoords="offset points",
        box_alignment=(.5, offset),
        bboxprops={"edgecolor" : "k",
        "facecolor":'k'})

ax[0].add_artist(ab)

arr_img = plt.imread('0%i.png', format='png')

imagebox = OffsetImage(arr_img, zoom=0.1)
imagebox.image.axes = ax[0]

ab = AnnotationBbox(imagebox, (0,0),
        xybox=(0, -7),
        xycoords=("data", "axes fraction"),
        boxcoords="offset points",
        box_alignment=(.5, offset),
        bboxprops={"edgecolor" : "k",
        "facecolor":'k'})

ax[0].add_artist(ab)
arr_img = plt.imread('5%gd.png', format='png')

imagebox = OffsetImage(arr_img, zoom=0.1)
imagebox.image.axes = ax[1]

ab = AnnotationBbox(imagebox, (5,0),
        xybox=(0, -7),
        xycoords=("data", "axes fraction"),
        boxcoords="offset points",
        box_alignment=(.5, offset),
        bboxprops={"edgecolor" : "k",
        "facecolor":'k'})

ax[1].add_artist(ab)

arr_img = plt.imread('2%gd.png', format='png')

imagebox = OffsetImage(arr_img, zoom=0.1)
imagebox.image.axes = ax[1]

ab = AnnotationBbox(imagebox, (2,0),
        xybox=(0, -7),
        xycoords=("data", "axes fraction"),
        boxcoords="offset points",
        box_alignment=(.5, offset),
        bboxprops={"edgecolor" : "k",
        "facecolor":'k'})

ax[1].add_artist(ab)

arr_img = plt.imread('0%gd.png', format='png')

imagebox = OffsetImage(arr_img, zoom=0.1)
imagebox.image.axes = ax[1]

ab = AnnotationBbox(imagebox, (0,0),
        xybox=(0, -7),
        xycoords=("data", "axes fraction"),
        boxcoords="offset points",
        box_alignment=(.5, offset),
        bboxprops={"edgecolor" : "k",
        "facecolor":'k'})

ax[1].add_artist(ab)

ax[0].plot(5, np.mean(i5), marker='x',
  color=(1.0,0,1.0))
indices[0] += 1
ax[1].plot(5, np.mean(gd5),
  color=(0,1.0,0),marker='x',)
indices[0] += 1
ax[2].plot(5, np.mean(au5),
  color='#FFA500',marker='x',)
indices[0] += 1
indices[0] += 1

ax[0].plot(1, np.mean(i1), color=(1.0,0,1.0),marker='x')
indices[0] += 1
ax[1].plot(2, np.mean(gd1), color=(0,1.0,0),marker='x')
indices[0] += 1
ax[2].plot(1, np.mean(au1), color='#FFA500',marker='x')
indices[0] += 1
indices[0] += 1


# ax[0].plot(0, np.mean(i0),color=(1.0,0,1.0),marker='x')
# indices[0] += 1
# ax[1].plot(0, np.mean(gd0),color=(0,1.0,0),marker='x')
# indices[0] += 1
# ax[2].plot(0, np.mean(au0),color='#FFA500',marker='x')  

# import ipdb;ipdb.set_trace()
x = [0,1,5]
y = [np.mean(i1),np.mean(i5)]
ax[0].plot(np.unique(x), np.poly1d(np.polyfit(x[1:], y, 1))(np.unique(x)),'--', color=(1.0,0,1.0),linewidth=0.5,label='Linear fit')

x = [0,2,5]
y = [np.mean(gd1),np.mean(gd5)]
ax[1].plot(np.unique(x), np.poly1d(np.polyfit(x[1:], y, 1))(np.unique(x)),'--g',linewidth=0.5,label='Linear fit')

x = [0,1,5]
x2 = [0,0.4,2]
y = [np.mean(au1),np.mean(au5)]
ax[2].plot(np.unique(x), np.poly1d(np.polyfit(x[1:], y, 1))(np.unique(x)),'--', color='#FFA500',linewidth=0.5,label='Linear fit')

# x = [0,1,5]
# ax[0].plot(x, x, color='k',linewidth=0.5,label='Theoretical')

# x = [0,2,5]
# ax[1].plot(x, x, color='k',linewidth=0.5,label='Theoretical')

# x = [0,1,5]
# ax[2].plot(x, x2, color='k',linewidth=0.5,label='Theoretical')
#fig.patch.set_facecolor('k')
SIZE = 14
ax[2].set_title('c) Gold',fontsize=SIZE)
ax[0].set_title('a) Iodine',fontsize=SIZE)
ax[1].set_title('b) Gadolinium',fontsize=SIZE)

ax[2].set_ylabel('%Au',fontsize=SIZE)
ax[0].set_ylabel('%I',fontsize=SIZE)
ax[1].set_ylabel('%Gd',fontsize=SIZE)

ax[2].set_xlabel('ROI',fontsize=SIZE)
ax[0].set_xlabel('ROI',fontsize=SIZE)
ax[1].set_xlabel('            ROI',fontsize=SIZE)
ax[0].grid(True)
ax[1].grid(True)
ax[2].grid(True)
#ax[0,0].legend(loc=0, fontsize=SIZE)

ax[0].set_xticks([0,1,2,3,4,5])
ax[0].set_xticklabels(['0%','1%','','','','5%'])
ax[1].set_xticks([0,1,2,3,4,5])
ax[1].set_xticklabels(['0%','','2%','','','5%'])    
ax[2].set_xticks([0,1,2,3,4,5])
ax[2].set_xticklabels(['0%','0.4%','','','','2%'])

# ax[0].set_yticks([0,1,2,3,4,5])
# ax[1].set_yticks([0,1,2,3,4,5])   
# ax[2].set_yticks([0,0.4,0.8,1.2,1.6,2])

ax[0].legend(loc=4)
ax[1].legend(loc=4)              
ax[2].legend(loc=4)             

plt.subplots_adjust(hspace = 0.4)

fig.tight_layout()
plt.savefig('Figure7.eps',format='eps')
plt.savefig('concentrations.png')

ct_image_Au[ct_image_Au < 0] = 0
ct_image_I[ct_image_I < 0] = 0
ct_image_Gd[ct_image_Gd < 0] = 0

ct_image_Au[ct_image_Au > 5] = 5
ct_image_I[ct_image_I > 5] = 5
ct_image_Gd[ct_image_Gd > 5] = 5

im_1 = np.zeros(that3.shape)
im_2 = np.zeros(that3.shape)
im_3 = np.zeros(that3.shape)

im_1[that3 == 0] = 1
im_2[that3 == 1] = 1
im_3[that3 == 2] = 1
# Out:
# C:\ProgramData\Miniconda3\lib\site-packages\ipykernel_launcher.py:71: RuntimeWarning: invalid value encountered in true_divide
# C:\ProgramData\Miniconda3\lib\site-packages\ipykernel_launcher.py:77: RuntimeWarning: invalid value encountered in true_divide
# C:\ProgramData\Miniconda3\lib\site-packages\ipykernel_launcher.py:83: RuntimeWarning: invalid value encountered in true_divide
# C:\ProgramData\Miniconda3\lib\site-packages\ipykernel_launcher.py:89: RuntimeWarning: invalid value encountered in true_divide
# C:\ProgramData\Miniconda3\lib\site-packages\ipykernel_launcher.py:95: RuntimeWarning: invalid value encountered in true_divide
# C:\ProgramData\Miniconda3\lib\site-packages\ipykernel_launcher.py:101: RuntimeWarning: invalid value encountered in true_divide
# C:\ProgramData\Miniconda3\lib\site-packages\ipykernel_launcher.py:107: RuntimeWarning: invalid value encountered in true_divide
# C:\ProgramData\Miniconda3\lib\site-packages\ipykernel_launcher.py:188: RuntimeWarning: invalid value encountered in less
# C:\ProgramData\Miniconda3\lib\site-packages\ipykernel_launcher.py:189: RuntimeWarning: invalid value encountered in less
# C:\ProgramData\Miniconda3\lib\site-packages\ipykernel_launcher.py:190: RuntimeWarning: invalid value encountered in less
# C:\ProgramData\Miniconda3\lib\site-packages\ipykernel_launcher.py:192: RuntimeWarning: invalid value encountered in greater
# C:\ProgramData\Miniconda3\lib\site-packages\ipykernel_launcher.py:193: RuntimeWarning: invalid value encountered in greater
# C:\ProgramData\Miniconda3\lib\site-packages\ipykernel_launcher.py:194: RuntimeWarning: invalid value encountered in greater
# Energy bin: K-edge SEC5 - SEC4
# CNR of 1% Au vial:  nan  +/-  nan
# CNR of 5% Au vial:  nan  +/-  nan
# Energy bin: K-edge SEC3 - SEC2
# CNR of 1% Gd vial:  nan  +/-  nan
# CNR of 5% Gd vial:  nan  +/-  nan
# Energy bin: K-edge SEC1 - SEC0
# CNR of 1% I vial:  nan  +/-  nan
# CNR of 5% I vial:  nan  +/-  nan
# Energy bin: K-edge SEC5 - SEC4
# CNR of 1% Au vial:  nan  +/-  nan
# CNR of 5% Au vial:  nan  +/-  nan
# Energy bin: K-edge SEC3 - SEC2
# CNR of 1% Gd vial:  nan  +/-  nan
# CNR of 5% Gd vial:  nan  +/-  nan
# Energy bin: K-edge SEC1 - SEC0
# CNR of 1% I vial:  nan  +/-  nan
# CNR of 5% I vial:  nan  +/-  nan
# Energy bin: K-edge SEC5 - SEC4
# CNR of 1% Au vial:  nan  +/-  nan
# CNR of 5% Au vial:  nan  +/-  nan
# Energy bin: K-edge SEC3 - SEC2
# CNR of 1% Gd vial:  nan  +/-  nan
# CNR of 5% Gd vial:  nan  +/-  nan
# Energy bin: K-edge SEC1 - SEC0
# CNR of 1% I vial:  nan  +/-  nan
# CNR of 5% I vial:  nan  +/-  nan
# Energy bin: K-edge SEC5 - SEC4
# CNR of 1% Au vial:  9.869084276663965  +/-  1.0
# CNR of 5% Au vial:  8.58347709309382  +/-  3.033189620451318
# Energy bin: K-edge SEC3 - SEC2
# CNR of 1% Gd vial:  4.3844737110295195  +/-  1.0598548083027353
# CNR of 5% Gd vial:  4.182679093703466  +/-  1.0
# Energy bin: K-edge SEC1 - SEC0
# CNR of 1% I vial:  10.637573901192864  +/-  1.0
# CNR of 5% I vial:  10.64152761923748  +/-  1.107463021258388
# C:\ProgramData\Miniconda3\lib\site-packages\ipykernel_launcher.py:227: RuntimeWarning: divide by zero encountered in double_scalars
# Energy bin: K-edge SEC5 - SEC4
# CNR of 1% Au vial:  0.849859135890215  +/-  1.4906350342760037
# CNR of 5% Au vial:  9.852609781752172  +/-  1.6875895875852966
# Energy bin: K-edge SEC3 - SEC2
# CNR of 1% Gd vial:  2.611142847943267  +/-  2.2509678524031678
# CNR of 5% Gd vial:  12.467323583927495  +/-  4.118387397008134
# Energy bin: K-edge SEC1 - SEC0
# CNR of 1% I vial:  12.809007933135574  +/-  1.9690448461420968
# CNR of 5% I vial:  67.36078382447408  +/-  2.3170173707447645
# Energy bin: K-edge SEC5 - SEC4
# CNR of 1% Au vial:  2.6276458035140826  +/-  3.185589644430894
# CNR of 5% Au vial:  12.828056351973258  +/-  3.2616801644202247
# Energy bin: K-edge SEC3 - SEC2
# CNR of 1% Gd vial:  6.786560339702526  +/-  4.23768494653051
# CNR of 5% Gd vial:  28.440640765690418  +/-  4.932711369782235
# Energy bin: K-edge SEC1 - SEC0
# CNR of 1% I vial:  10.604727615851237  +/-  1.434234881104931
# CNR of 5% I vial:  56.62931545216334  +/-  1.548981023149253
# Energy bin: K-edge SEC5 - SEC4
# CNR of 1% Au vial:  1.413277586343343  +/-  1.6124932831716692
# CNR of 5% Au vial:  9.529037835179988  +/-  1.7316805524652077
# Energy bin: K-edge SEC3 - SEC2
# CNR of 1% Gd vial:  9.133781920142336  +/-  2.860924369170711
# CNR of 5% Gd vial:  27.244779868645765  +/-  5.329179296478175
# Energy bin: K-edge SEC1 - SEC0
# CNR of 1% I vial:  14.99668647542326  +/-  2.254171855300232
# CNR of 5% I vial:  75.98038522714192  +/-  2.857950459228032
# Energy bin: K-edge SEC5 - SEC4
# CNR of 1% Au vial:  3.288582171407122  +/-  2.6061653294112688
# CNR of 5% Au vial:  14.650617508362668  +/-  3.7595521005178956
# Energy bin: K-edge SEC3 - SEC2
# CNR of 1% Gd vial:  6.924930073988745  +/-  2.42419456566076
# CNR of 5% Gd vial:  16.70304961621601  +/-  3.390696817136195
# Energy bin: K-edge SEC1 - SEC0
# CNR of 1% I vial:  24.716173463373348  +/-  4.910705057757195
# CNR of 5% I vial:  122.07337221916454  +/-  4.608007199552763
# Energy bin: K-edge SEC5 - SEC4
# CNR of 1% Au vial:  3.0269857805365428  +/-  1.9186018695817701
# CNR of 5% Au vial:  15.603762227743381  +/-  2.291081473465593
# Energy bin: K-edge SEC3 - SEC2
# CNR of 1% Gd vial:  11.558571218102077  +/-  3.7295829167530363
# CNR of 5% Gd vial:  30.47770547094153  +/-  3.698434670399804
# Energy bin: K-edge SEC1 - SEC0
# CNR of 1% I vial:  20.2684414132007  +/-  3.177780717841453
# CNR of 5% I vial:  102.37772782611849  +/-  2.9070133617111624
# Energy bin: K-edge SEC5 - SEC4
# CNR of 1% Au vial:  1.7082955408004432  +/-  2.1497889757564907
# CNR of 5% Au vial:  11.81724463627429  +/-  1.865424476618966
# Energy bin: K-edge SEC3 - SEC2
# CNR of 1% Gd vial:  8.881865907435524  +/-  2.7254944280659634
# CNR of 5% Gd vial:  23.80088236266193  +/-  3.030700244802148
# Energy bin: K-edge SEC1 - SEC0
# CNR of 1% I vial:  12.066427587214852  +/-  1.5859997323789414
# CNR of 5% I vial:  64.83119695678899  +/-  2.0223338745458657
# Energy bin: K-edge SEC5 - SEC4
# CNR of 1% Au vial:  4.65032772421618  +/-  4.4446236879664065
# CNR of 5% Au vial:  20.374641393893466  +/-  5.77869895266807
# Energy bin: K-edge SEC3 - SEC2
# CNR of 1% Gd vial:  6.841983939179287  +/-  2.145074483084829
# CNR of 5% Gd vial:  19.839830710056628  +/-  3.1447128120288808
# Energy bin: K-edge SEC1 - SEC0
# CNR of 1% I vial:  19.271149439480148  +/-  2.7114230905905745
# CNR of 5% I vial:  97.12708679357306  +/-  3.5688709154102503
# Energy bin: K-edge SEC5 - SEC4
# CNR of 1% Au vial:  4.188893900136159  +/-  2.1896337596861084
# CNR of 5% Au vial:  19.099074680804634  +/-  2.472043565587696
# Energy bin: K-edge SEC3 - SEC2
# CNR of 1% Gd vial:  7.534858437938931  +/-  2.6299562443758617
# CNR of 5% Gd vial:  19.8067587470814  +/-  2.814717555376789
# Energy bin: K-edge SEC1 - SEC0
# CNR of 1% I vial:  8.563368086545525  +/-  2.0793585591817063
# CNR of 5% I vial:  49.35032617457463  +/-  1.8159948774409362
# Energy bin: K-edge SEC5 - SEC4
# CNR of 1% Au vial:  2.932827545403497  +/-  2.448451888094075
# CNR of 5% Au vial:  18.49940741191624  +/-  2.212897518408544
# Energy bin: K-edge SEC3 - SEC2
# CNR of 1% Gd vial:  8.177409115812747  +/-  3.3950530758202238
# CNR of 5% Gd vial:  19.388812129110367  +/-  2.8075354901517438
# Energy bin: K-edge SEC1 - SEC0
# CNR of 1% I vial:  17.537622476298843  +/-  3.9101353202922944
# CNR of 5% I vial:  95.56977735723142  +/-  3.564212761824472
# Energy bin: K-edge SEC5 - SEC4
# CNR of 1% Au vial:  4.422015806752833  +/-  2.3430733343155623
# CNR of 5% Au vial:  22.685334230077288  +/-  2.1553179498433352
# Energy bin: K-edge SEC3 - SEC2
# CNR of 1% Gd vial:  9.581681232165092  +/-  2.468051191289911
# CNR of 5% Gd vial:  19.790693670468144  +/-  3.303065442049118
# Energy bin: K-edge SEC1 - SEC0
# CNR of 1% I vial:  8.617397139826847  +/-  3.4055277879866286
# CNR of 5% I vial:  50.9245791778684  +/-  3.14426148723472
# Energy bin: K-edge SEC5 - SEC4
# CNR of 1% Au vial:  2.9897552877333418  +/-  1.9458823699100676
# CNR of 5% Au vial:  13.461078165716893  +/-  2.1823240426631174
# Energy bin: K-edge SEC3 - SEC2
# CNR of 1% Gd vial:  5.242747454658251  +/-  2.3295178512644688
# CNR of 5% Gd vial:  16.13466346698806  +/-  2.1761168102803903
# Energy bin: K-edge SEC1 - SEC0
# CNR of 1% I vial:  18.576365502535594  +/-  2.1695032721658873
# CNR of 5% I vial:  94.05391175105315  +/-  2.283972508716989
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-58-b2a38c7be591> in <module>
#     406 x = [0,1,5]
#     407 y = [np.mean(i1),np.mean(i5)]
# --> 408 ax[0].plot(np.unique(x), np.poly1d(np.polyfit(x[1:], y, 1))(np.unique(x)),'--', color=(1.0,0,1.0),linewidth=0.5,label='Linear fit')
#     409
#     410 x = [0,2,5]
#
# C:\ProgramData\Miniconda3\lib\site-packages\numpy\lib\polynomial.py in polyfit(x, y, deg, rcond, full, w, cov)
#     578     scale = NX.sqrt((lhs*lhs).sum(axis=0))
#     579     lhs /= scale
# --> 580     c, resids, rank, s = lstsq(lhs, rhs, rcond)
#     581     c = (c.T/scale).T  # broadcast scale coefficients
#     582
#
# C:\ProgramData\Miniconda3\lib\site-packages\numpy\linalg\linalg.py in lstsq(a, b, rcond)
#    2154     signature = 'DDd->Ddid' if isComplexType(t) else 'ddd->ddid'
#    2155     extobj = get_linalg_error_extobj(_raise_linalgerror_lstsq)
# -> 2156     x, resids, rank, s = gufunc(a, b, rcond, signature=signature, extobj=extobj)
#    2157
#    2158     # remove the axis we added
#
# C:\ProgramData\Miniconda3\lib\site-packages\numpy\linalg\linalg.py in _raise_linalgerror_lstsq(err, flag)
#      99
#     100 def _raise_linalgerror_lstsq(err, flag):
# --> 101     raise LinAlgError("SVD did not converge in Linear Least Squares")
#     102
#     103 def get_linalg_error_extobj(callback):
#
# LinAlgError: SVD did not converge in Linear Least Squares

# %%
np.poly1d(np.polyfit(x[1:], y, 1))(np.unique(x))
# Out:
# array([ 6.78283196, 11.37912972, 29.76432077])

# %%
Iodine = [[29.6, 11.5, 12.6, 17.4, 10.0, 9.8, 6.2, 8.8],
[149.4, 42.1, 45.4, 66.1, 37.3, 33.1, 17.7, 42.4]]
Gadolinium = [
[10.6, 1.7, 1.3, 1.0, 0.2, 1.0, 0.2, 16.1],
[26.5, 6.8, 7.1, 7.5, 7.3, 11.0, 4.7, 4.6]]
Gold = [
[4.4, 8.7, 8.9, 8.9, 5.2, 5.9, 5.3, 3.8],
[22.4, 27.9, 28.1, 26.0, 13.5, 13.5, 13.3, 18.8]]

# %%
plt.figure()
plt.bar(range(1,13),
        [Iodine[1][0],Iodine[0][0],Gadolinium[1][0],Gadolinium[0][0],
         Gold[1][0],Gold[0][0],
        Iodine[1][-1],Iodine[0][-1],Gadolinium[1][-1],Gadolinium[0][-1],
         Gold[1][-1],Gold[0][-1]])
# Out:
# <BarContainer object of 12 artists>

# %%
'''
After running main() method, do the K-edge subtraction
:return:
'''
from scipy import stats

slice_no = 15
m = 16

radius = 1.593
directory = "./images"
#dir_data = "./data_no_smoothing/"

#for i in range(15,16):
i = 15


img0 = sio.loadmat(dir_data + "binSEC0_multiplex_corrected2.mat")['Reconimg'][:,:,slice_no]
img1 = sio.loadmat(dir_data + "binSEC1_multiplex_corrected2.mat")['Reconimg'][:,:,slice_no]
img2 = sio.loadmat(dir_data + "binSEC2_multiplex_corrected2.mat")['Reconimg'][:,:,slice_no]
img3 = sio.loadmat(dir_data + "binSEC3_multiplex_corrected2.mat")['Reconimg'][:,:,slice_no]
img4 = sio.loadmat(dir_data + "binSEC4_multiplex_corrected2.mat")['Reconimg'][:,:,slice_no]
img5 = sio.loadmat(dir_data + "binSEC5_multiplex_corrected2.mat")['Reconimg'][:,:,slice_no]
img6 = sio.loadmat(dir_data + "binSEC6_multiplex_corrected2.mat")['Reconimg'][:,:,slice_no]
#import ipdb; ipdb.set_trace() 

size = np.shape(img0)[0] #same size as all 3 here

noise_roi = getBackgroundRegion(size)

#mask_background0 = img0*noise_roi
# mask_background1 = img1*noise_roi
# mask_background2 = img2*noise_roi
# mask_background3 = img3*noise_roi
# mask_background4 = img4*noise_roi
# mask_background5 = img5*noise_roi


# signal_background0= np.average(mask_background0[mask_background0 != 0])
# signal_background1= np.average(mask_background1[mask_background1 != 0])
# signal_background2= np.average(mask_background2[mask_background2 != 0])
# signal_background3= np.average(mask_background3[mask_background3 != 0])
# signal_background4= np.average(mask_background4[mask_background4 != 0])
# signal_background5= np.average(mask_background5[mask_background5 != 0])

# img0 = img0 / signal_background0
# img1 = img1 / signal_background1
# img2 = img2 / signal_background2
# img3 = img3 / signal_background3
# img4 = img4 / signal_background4
# img5 = img5 / signal_background5

# img0[img0 < signal_background0 - 0.05] = 0
# img1[img1 < signal_background1 - 0.05] = 0
# img2[img2 < signal_background2 - 0.05] = 0
# img3[img3 < signal_background3 - 0.05] = 0
# img4[img4 < signal_background4 - 0.05] = 0
# img5[img5 < signal_background5 - 0.05] = 0
'''
plt.figure(77)
plt.imshow(img0)
plt.figure(78)
plt.imshow(img1)
'''
img_I = (img1 - img0)
img_Gd = (img3  - img2)
img_Au = (img5  - img4)

# img_I[img_I < -0.003] = 0
# img_Gd[img_Gd < -0.001] = 0
# img_Au[img_Au < 0.0019] = 0
# img_I[img_I > 0.1] = 0
# img_Gd[img_Gd > 0.12] = 0
# img_Au[img_Au > 0.07] = 0
# #size = np.shape(img_I)[0] #same size as all 3 here

noise_roi = getBackgroundRegion(size)
air_roi = getAirRegion(size)

number_of_noise_pixels = np.sum(noise_roi)
number_of_air_pixels = np.sum(air_roi)

noise_fbp_image = noise_roi * img0
noise_air_image = air_roi * img0
background_noise0 = np.sum(noise_fbp_image) / number_of_noise_pixels
air_noise0 = np.sum(noise_air_image) / number_of_air_pixels
ct_image0 = 1000 * ((img0 - background_noise0)/(background_noise0 - air_noise0))

noise_fbp_image = noise_roi * img1
noise_air_image = air_roi * img1
background_noise1 = np.sum(noise_fbp_image) / number_of_noise_pixels
air_noise1 = np.sum(noise_air_image) / number_of_air_pixels
ct_image1 = 1000 * ((img1  - background_noise1)/(background_noise1 - air_noise1))

noise_fbp_image = noise_roi * img2
noise_air_image = air_roi * img2  
background_noise2 = np.sum(noise_fbp_image) / number_of_noise_pixels
air_noise2 = np.sum(noise_air_image) / number_of_air_pixels
ct_image2 = 1000 * ((img2 - background_noise2)/(background_noise2 - air_noise2)) 

noise_fbp_image = noise_roi * img3
noise_air_image = air_roi * img3
background_noise3 = np.sum(noise_fbp_image) / number_of_noise_pixels
air_noise3 = np.sum(noise_air_image) / number_of_air_pixels
ct_image3 = 1000 * ((img3 - background_noise3)/(background_noise3 - air_noise3))

noise_fbp_image = noise_roi * img4
noise_air_image = air_roi * img4  
background_noise4 = np.sum(noise_fbp_image) / number_of_noise_pixels
air_noise4 = np.sum(noise_air_image) / number_of_air_pixels
ct_image4 = 1000 * ((img4 - background_noise4)/(background_noise4 - air_noise4))

noise_fbp_image = noise_roi * img5
noise_air_image = air_roi * img5  
background_noise5 = np.sum(noise_fbp_image) / number_of_noise_pixels
air_noise5 = np.sum(noise_air_image) / number_of_air_pixels
ct_image5 = 1000 * ((img5 - background_noise5)/(background_noise5 - air_noise5))

noise_fbp_image = noise_roi * img6
noise_air_image = air_roi * img6  
background_noise6 = np.sum(noise_fbp_image) / number_of_noise_pixels
air_noise6 = np.sum(noise_air_image) / number_of_air_pixels
ct_image6 = 1000 * ((img6 - background_noise6)/(background_noise6 - air_noise6))

ct_image_I = (ct_image2 - ct_image0)
ct_image_Gd = (ct_image3  - ct_image2)
ct_image_Au = (ct_image5  - ct_image4)

gold5_roi = getVialRegion("vial5Au", size)
gold1_roi = getVialRegion("vial1Au", size)
gadolinium5_roi = getVialRegion("vial5Gd", size)
gadolinium1_roi = getVialRegion("vial1Gd", size)
iodine5_roi = getVialRegion("vial5I", size)
iodine1_roi = getVialRegion("vial1I", size)
noise_roi = getBackgroundRegion(size)

np_Gd = np.sum(gadolinium5_roi)
np_Au = np.sum(gold5_roi)
np_I = np.sum(iodine5_roi)

av_Gd = np.sum(gadolinium5_roi*ct_image_Gd) /np_Gd 
av_Au = np.sum(gold5_roi*ct_image_Au)       /np_Au
av_I  = np.sum(iodine5_roi*ct_image_I)      /np_I

ct_image_I /= av_I
ct_image_Au /= av_Au
ct_image_Gd /= av_Gd

ct_image_I *= 5
ct_image_Au *= 2
ct_image_Gd *= 5

ct_image_Au[ct_image_Au < 0] = 0
ct_image_I[ct_image_I < 0] = 0
ct_image_Gd[ct_image_Gd < 0] = 0

ct_image_Au[ct_image_Au > 300] = 300
ct_image_I[ct_image_I > 300] = 300
ct_image_Gd[ct_image_Gd > 300] = 300

TEXT_SIZE = 8

fig, ax = plt.subplots(nrows=2,ncols=2)

im = ax[1,1].imshow(ct_image6, extent=(-radius,radius,-radius,radius), cmap=plt.get_cmap("gray"), vmin = -1000)

cbar = fig.colorbar(im, ax=ax[1,1])
cbar.set_label("HU", rotation=270,labelpad=TEXT_SIZE,size=TEXT_SIZE)
#ax[1,1].set_xticks(size= TEXT_SIZE)
#ax[1,1].set_yticks(size = TEXT_SIZE)
ax[1,1].set_xlabel("x [cm]",size=TEXT_SIZE,labelpad=2)
ax[1,1].set_ylabel("y [cm]",size=TEXT_SIZE,labelpad=1)
ax[1,1].set_xticks(ticks = [-1.5, 0, 1.5])
ax[1,1].set_yticks(ticks = [-1.5, 0, 1.5])
ax[1,1].set_title('d) CT image',size=TEXT_SIZE)

inds = np.asarray([
        [0.043384339242731656, -0.8685768839103873],
        [0.8455737486113676, -0.41031619144602895],
        [0.8255065388354005, 0.4471379837067202],
        [0.064384339242731656, 0.8953314663951112],
        [-0.703338675013887, 0.4320707739307531],
        [-0.728050701259043, -0.372538340122199655],
        [0.6398425877152363, -0.9968416496945014]])

size = 0.23
for ii in range(inds.shape[0]):
    # import ipdb;ipdb.set_trace()
    circle = plt.Circle((inds[ii,0], inds[ii,1]), size, color='r', fill=False)
    ax[1,1].add_artist(circle)

im = ax[0,0].imshow(ct_image_I, extent=(-radius,radius,-radius,radius), cmap=purp, vmin = 0, vmax = 5)

cbar = fig.colorbar(im, ax=ax[0,0])
cbar.set_label("% I", rotation=270,labelpad=TEXT_SIZE,size=TEXT_SIZE)
#ax[0,0].set_xticks(size= TEXT_SIZE)
#ax[0,0].set_yticks(size = TEXT_SIZE)
ax[0,0].set_xlabel("x [cm]",size=TEXT_SIZE,labelpad=2)
ax[0,0].set_ylabel("y [cm]",size=TEXT_SIZE,labelpad=1)
ax[0,0].set_xticks(ticks = [-1.5, 0, 1.5])
ax[0,0].set_yticks(ticks = [-1.5, 0, 1.5])
ax[0,0].set_title('a) Iodine',size=TEXT_SIZE)

im = ax[0,1].imshow(ct_image_Gd, extent=(-radius,radius,-radius,radius), cmap=green, vmin = 0, vmax = 5)

cbar = fig.colorbar(im, ax=ax[0,1])
cbar.set_label("% Gd", rotation=270,labelpad=TEXT_SIZE,size=TEXT_SIZE)
#ax[0,0].set_xticks(size= TEXT_SIZE)
#ax[0,0].set_yticks(size = TEXT_SIZE)
ax[0,1].set_xlabel("x [cm]",size=TEXT_SIZE,labelpad=2)
ax[0,1].set_ylabel("y [cm]",size=TEXT_SIZE,labelpad=1)
ax[0,1].set_xticks(ticks = [-1.5, 0, 1.5])
ax[0,1].set_yticks(ticks = [-1.5, 0, 1.5])
ax[0,1].set_title('b) Gadolinium',size=TEXT_SIZE)

im = ax[1,0].imshow(ct_image_Au, extent=(-radius,radius,-radius,radius), cmap=gold, vmin = 0, vmax = 2)

cbar = fig.colorbar(im, ax=ax[1,0])
cbar.set_label("% Au", rotation=270,labelpad=TEXT_SIZE,size=TEXT_SIZE)
#ax[0,0].set_xticks(size= TEXT_SIZE)
#ax[0,0].set_yticks(size = TEXT_SIZE)
ax[1,0].set_xlabel("x [cm]",size=TEXT_SIZE,labelpad=2)
ax[1,0].set_ylabel("y [cm]",size=TEXT_SIZE,labelpad=1)
ax[1,0].set_xticks(ticks = [-1.5, 0, 1.5])
ax[1,0].set_yticks(ticks = [-1.5, 0, 1.5])
ax[1,0].set_title('c) Gold',size=TEXT_SIZE)


ct_image_Au[ct_image_Au < 0] = 0
ct_image_I[ct_image_I < 0] = 0
ct_image_Gd[ct_image_Gd < 0] = 0

ct_image_Au[ct_image_Au > 300] = 300
ct_image_I[ct_image_I > 300] = 300
ct_image_Gd[ct_image_Gd > 300] = 300

# calculate cnr
cnr_gold1, err_gold1, cnr_gold5, err_gold5 = calculateCNR(ct_image_Au, gold1_roi, gold5_roi, noise_roi)
print("Energy bin: K-edge SEC5 - SEC4")
print("CNR of 1% Au vial: ", cnr_gold1, " +/- ", err_gold1)
print("CNR of 5% Au vial: ", cnr_gold5, " +/- ", err_gold5)

cnr_gadolinium1, err_gadolinium1, cnr_gadolinium5, err_gadolinium5 = calculateCNR(ct_image_Gd, gadolinium1_roi,
                                                                                  gadolinium5_roi, noise_roi)
print( "Energy bin: K-edge SEC3 - SEC2")
print( "CNR of 1% Gd vial: ", cnr_gadolinium1, " +/- ", err_gadolinium1)
print( "CNR of 5% Gd vial: ", cnr_gadolinium5, " +/- ", err_gadolinium5)

cnr_iodine1, err_iodine1, cnr_iodine5, err_iodine5 = calculateCNR(ct_image_I, iodine1_roi,
                                                                  iodine5_roi, noise_roi)
print( "Energy bin: K-edge SEC1 - SEC0")
print( "CNR of 1% I vial: ", cnr_iodine1, " +/- ", err_iodine1)
print( "CNR of 5% I vial: ", cnr_iodine5, " +/- ", err_iodine5)

i5 = []
gd5 = []
au5 = []

i1 = []
gd1 = []
au1 = []

i0 = []
gd0 = []
au0 = []

i5.append(cnr_iodine5)
gd5.append(cnr_gadolinium5)
au5.append(cnr_gold5)

i1.append(cnr_iodine1)
gd1.append(cnr_gadolinium1)
au1.append(cnr_gold1)


fig, ax = plt.subplots(nrows=3,ncols=1,figsize=(10,10), dpi=300)

ax[0] = plt.subplot(2, 2, 1)
ax[1] = plt.subplot(2, 2, 2)
ax[2] = plt.subplot(2, 2, 3)


SIZE = 8
width = 0.1
indices = [0] 
    
arr_img = plt.imread('5%au.png', format='png')

imagebox = OffsetImage(arr_img, zoom=0.1)
imagebox.image.axes = ax[2]
offset = 1.9

ab = AnnotationBbox(imagebox, (5,0),
        xybox=(0, -7),
        xycoords=("data", "axes fraction"),
        boxcoords="offset points",
        box_alignment=(.5, offset),
        bboxprops={"edgecolor" : "k",
        "facecolor":'k'})

ax[2].add_artist(ab)

arr_img = plt.imread('1%au.png', format='png')

imagebox = OffsetImage(arr_img, zoom=0.1)
imagebox.image.axes = ax[2]

ab = AnnotationBbox(imagebox, (1,0),
        xybox=(0, -7),
        xycoords=("data", "axes fraction"),
        boxcoords="offset points",
        box_alignment=(.5, offset),
        bboxprops={"edgecolor" : "k",
        "facecolor":'k'})

ax[2].add_artist(ab)

arr_img = plt.imread('0%au.png', format='png')

imagebox = OffsetImage(arr_img, zoom=0.1)
imagebox.image.axes = ax[2]

ab = AnnotationBbox(imagebox, (0,0),
        xybox=(0, -7),
        xycoords=("data", "axes fraction"),
        boxcoords="offset points",
        box_alignment=(.5, offset),
        bboxprops={"edgecolor" : "k",
        "facecolor":'k'})

ax[2].add_artist(ab)

arr_img = plt.imread('5%i.png', format='png')

imagebox = OffsetImage(arr_img, zoom=0.1)
imagebox.image.axes = ax[0]

ab = AnnotationBbox(imagebox, (5,0),
        xybox=(0, -7),
        xycoords=("data", "axes fraction"),
        boxcoords="offset points",
        box_alignment=(.5, offset),
        bboxprops={"edgecolor" : "k",
        "facecolor":'k'})

ax[0].add_artist(ab)

arr_img = plt.imread('1%i.png', format='png')

imagebox = OffsetImage(arr_img, zoom=0.1)
imagebox.image.axes = ax[0]

ab = AnnotationBbox(imagebox, (1,0),
        xybox=(0, -7),
        xycoords=("data", "axes fraction"),
        boxcoords="offset points",
        box_alignment=(.5, offset),
        bboxprops={"edgecolor" : "k",
        "facecolor":'k'})

ax[0].add_artist(ab)

arr_img = plt.imread('0%i.png', format='png')

imagebox = OffsetImage(arr_img, zoom=0.1)
imagebox.image.axes = ax[0]

ab = AnnotationBbox(imagebox, (0,0),
        xybox=(0, -7),
        xycoords=("data", "axes fraction"),
        boxcoords="offset points",
        box_alignment=(.5, offset),
        bboxprops={"edgecolor" : "k",
        "facecolor":'k'})

ax[0].add_artist(ab)
arr_img = plt.imread('5%gd.png', format='png')

imagebox = OffsetImage(arr_img, zoom=0.1)
imagebox.image.axes = ax[1]

ab = AnnotationBbox(imagebox, (5,0),
        xybox=(0, -7),
        xycoords=("data", "axes fraction"),
        boxcoords="offset points",
        box_alignment=(.5, offset),
        bboxprops={"edgecolor" : "k",
        "facecolor":'k'})

ax[1].add_artist(ab)

arr_img = plt.imread('2%gd.png', format='png')

imagebox = OffsetImage(arr_img, zoom=0.1)
imagebox.image.axes = ax[1]

ab = AnnotationBbox(imagebox, (2,0),
        xybox=(0, -7),
        xycoords=("data", "axes fraction"),
        boxcoords="offset points",
        box_alignment=(.5, offset),
        bboxprops={"edgecolor" : "k",
        "facecolor":'k'})

ax[1].add_artist(ab)

arr_img = plt.imread('0%gd.png', format='png')

imagebox = OffsetImage(arr_img, zoom=0.1)
imagebox.image.axes = ax[1]

ab = AnnotationBbox(imagebox, (0,0),
        xybox=(0, -7),
        xycoords=("data", "axes fraction"),
        boxcoords="offset points",
        box_alignment=(.5, offset),
        bboxprops={"edgecolor" : "k",
        "facecolor":'k'})

ax[1].add_artist(ab)

ax[0].errorbar(5, np.mean(i5), yerr = err_iodine5, marker='x',
  color=(1.0,0,1.0))
indices[0] += 1
ax[1].errorbar(5, np.mean(gd5), yerr = err_gadolinium5,
  color=(0,1.0,0),marker='x',)
indices[0] += 1
ax[2].errorbar(5, np.mean(au5),  yerr = err_gold5,
  color='#FFA500',marker='x',)
indices[0] += 1
indices[0] += 1

ax[0].errorbar(1, np.mean(i1),  yerr = err_iodine1,color=(1.0,0,1.0),marker='x')
indices[0] += 1
ax[1].errorbar(2, np.mean(gd1),  yerr = err_gadolinium1,color=(0,1.0,0),marker='x')
indices[0] += 1
ax[2].errorbar(1, np.mean(au1),  yerr = err_gold1,color='#FFA500',marker='x')
indices[0] += 1
indices[0] += 1

ax[0].errorbar(5, np.mean(i5), yerr = err_iodine5, marker='x',
  color=(1.0,0,1.0))
indices[0] += 1
ax[1].errorbar(5, np.mean(gd5), yerr = err_gadolinium5,
  color=(0,1.0,0),marker='x',)
indices[0] += 1
ax[2].errorbar(5, np.mean(au5),  yerr = err_gold5,
  color='#FFA500',marker='x',)
indices[0] += 1
indices[0] += 1

ax[0].errorbar(1, np.mean(i1),  yerr = err_iodine1,color=(1.0,0,1.0),marker='x')
indices[0] += 1
ax[1].errorbar(2, np.mean(gd1),  yerr = err_gadolinium1,color=(0,1.0,0),marker='x')
indices[0] += 1
ax[2].errorbar(1, np.mean(au1),  yerr = err_gold1,color='#FFA500',marker='x')
indices[0] += 1
indices[0] += 1

# ax[0].plot(0, np.mean(i0),color=(1.0,0,1.0),marker='x')
# indices[0] += 1
# ax[1].plot(0, np.mean(gd0),color=(0,1.0,0),marker='x')
# indices[0] += 1
# ax[2].plot(0, np.mean(au0),color='#FFA500',marker='x')  

# import ipdb;ipdb.set_trace()
x = [0,1,5]
y = [np.mean(i1),np.mean(i5)]
ax[0].plot(np.unique(x), np.poly1d(np.polyfit(x[1:], y, 1))(np.unique(x)),'--', color=(1.0,0,1.0),linewidth=1,label='K-edge')

x = [0,2,5]
y = [np.mean(gd1),np.mean(gd5)]
ax[1].plot(np.unique(x), np.poly1d(np.polyfit(x[1:], y, 1))(np.unique(x)),'--g',linewidth=1,label='K-edge')

x = [0,1,5]
x2 = [0,0.4,2]
y = [np.mean(au1),np.mean(au5)]
ax[2].plot(np.unique(x), np.poly1d(np.polyfit(x[1:], y, 1))(np.unique(x)),'--', color='#FFA500',linewidth=1,label='K-edge')

# x = [0,1,5]
# ax[0].plot(x, x, color='k',linewidth=0.5,label='Theoretical')

# x = [0,2,5]
# ax[1].plot(x, x, color='k',linewidth=0.5,label='Theoretical')

# x = [0,1,5]
# ax[2].plot(x, x2, color='k',linewidth=0.5,label='Theoretical')
#fig.patch.set_facecolor('k')
SIZE = 14
ax[2].set_title('c) Gold',fontsize=SIZE)
ax[0].set_title('a) Iodine',fontsize=SIZE)
ax[1].set_title('b) Gadolinium',fontsize=SIZE)

ax[2].set_ylabel('CNR',fontsize=SIZE)
ax[0].set_ylabel('CNR',fontsize=SIZE)
ax[1].set_ylabel('CNR',fontsize=SIZE)

ax[2].set_xlabel('ROI',fontsize=SIZE)
ax[0].set_xlabel('ROI',fontsize=SIZE)
ax[1].set_xlabel('            ROI',fontsize=SIZE)
ax[0].grid(True)
ax[1].grid(True)
ax[2].grid(True)
#ax[0,0].legend(loc=0, fontsize=SIZE)

ax[0].set_xticks([0,1,2,3,4,5])
ax[0].set_xticklabels(['0%','1%','','','','5%'])
ax[1].set_xticks([0,1,2,3,4,5])
ax[1].set_xticklabels(['0%','','2%','','','5%'])    
ax[2].set_xticks([0,1,2,3,4,5])
ax[2].set_xticklabels(['0%','0.4%','','','','2%'])

plt.subplots_adjust(hspace = 0.8)

fig.tight_layout()
plt.savefig('Figure7.eps',format='eps')
plt.savefig('concentrations.png')

ct_image_Au[ct_image_Au < 0] = 0
ct_image_I[ct_image_I < 0] = 0
ct_image_Gd[ct_image_Gd < 0] = 0

ct_image_Au[ct_image_Au > 5] = 5
ct_image_I[ct_image_I > 5] = 5
ct_image_Gd[ct_image_Gd > 5] = 5

im_1 = np.zeros(that3.shape)
im_2 = np.zeros(that3.shape)
im_3 = np.zeros(that3.shape)

im_1[that3 == 0] = 1
im_2[that3 == 1] = 1
im_3[that3 == 2] = 1

# calculate cnr
cnr_gold1, err_gold1, cnr_gold5, err_gold5 = calculateCNR(ct_image6, gold1_roi, gold5_roi, noise_roi)
print("Energy bin: K-edge SEC5 - SEC4")
print("CNR of 1% Au vial: ", cnr_gold1, " +/- ", err_gold1)
print("CNR of 5% Au vial: ", cnr_gold5, " +/- ", err_gold5)

cnr_gadolinium1, err_gadolinium1, cnr_gadolinium5, err_gadolinium5 = calculateCNR(ct_image6, gadolinium1_roi,
                                                                                  gadolinium5_roi, noise_roi)
print( "Energy bin: K-edge SEC3 - SEC2")
print( "CNR of 1% Gd vial: ", cnr_gadolinium1, " +/- ", err_gadolinium1)
print( "CNR of 5% Gd vial: ", cnr_gadolinium5, " +/- ", err_gadolinium5)

cnr_iodine1, err_iodine1, cnr_iodine5, err_iodine5 = calculateCNR(ct_image6, iodine1_roi,
                                                                  iodine5_roi, noise_roi)
print( "Energy bin: K-edge SEC1 - SEC0")
print( "CNR of 1% I vial: ", cnr_iodine1, " +/- ", err_iodine1)
print( "CNR of 5% I vial: ", cnr_iodine5, " +/- ", err_iodine5)

i5 = []
gd5 = []
au5 = []

i1 = []
gd1 = []
au1 = []

i0 = []
gd0 = []
au0 = []

i5.append(cnr_iodine5)
gd5.append(cnr_gadolinium5)
au5.append(cnr_gold5)

i1.append(cnr_iodine1)
gd1.append(cnr_gadolinium1)
au1.append(cnr_gold1)


ax[0].errorbar(5, Iodine[1][-1], yerr = err_iodine5, marker='x',
  color='k')
indices[0] += 1
ax[1].errorbar(5,Gadolinium[1][-1] , yerr = err_gadolinium5,
  color='k',marker='x',)
indices[0] += 1
ax[2].errorbar(5, Gold[1][-1],  yerr = err_gold5,
  color='k',marker='x',)
indices[0] += 1
indices[0] += 1

ax[0].errorbar(1, Iodine[0][-1],  yerr = err_iodine1,color='k',marker='x')

indices[0] += 1
ax[1].errorbar(2, Gadolinium[0][-1],  yerr = err_gadolinium1,color='k',marker='x',label = 'Summed Image')

indices[0] += 1
ax[2].errorbar(1, Gold[0][-1],  yerr = err_gold1,color='k',marker='x')

indices[0] += 1
indices[0] += 1

x = [0,1,5]
y = [Iodine[0][-1],Iodine[1][-1]]
ax[0].plot(np.unique(x), np.poly1d(np.polyfit(x[1:], y, 1))(np.unique(x)), color='k',linewidth=1,label='Summed Image')

y = [0] + y
slope, intercept, r_value, s, t = stats.linregress(x,y)
print('iodine r2',r_value**2)
# x = [0,2,5]
# y = [Gadolinium[0][-1],Gadolinium[1][-1]]
# ax[1].plot(np.unique(x), np.poly1d(np.polyfit(x[1:], y, 1))(np.unique(x)),color='k',linewidth=1,label='Summed Image')

x = [0,1,5]
x2 = [0,0.4,2]
y = [Gold[0][-1],Gold[1][-1]]
ax[2].plot(np.unique(x), np.poly1d(np.polyfit(x[1:], y, 1))(np.unique(x)),color='k',linewidth=1,label='Summed Image')

y = [0] + y
slope, intercept, r_value, s, t = stats.linregress(x,y)
print('gold r2',r_value**2)

ax[0].axhline(4, color="r", linewidth=1, linestyle="--",label='Rose Criterion')
ax[1].axhline(4, color="r", linewidth=1, linestyle="--",label='Rose Criterion')
ax[2].axhline(4, color="r", linewidth=1, linestyle="--",label='Rose Criterion')
# ax[1].axhline(-4, color="r", linewidth=1, linestyle="--",label='Rose Criterion')

ax[0].legend(loc=0)
ax[1].legend(loc=0)              
ax[2].legend(loc=0)  

ax3 = plt.subplot(2, 2, 4)

indeces = [1]
width = 0.8

x = [0,1,5]
y = [Iodine[0][-1],Iodine[1][-1]]


# ax3.plot(np.unique(y), np.poly1d(np.polyfit( y,x[1:], 1))(np.unique(y)),color='k',linewidth=1,label='Summed Image')
ax3.bar(indeces, np.poly1d(np.polyfit(y,x[1:], 1))(4.), width=width,
        color='k')#, label='5% I')


print('min iodine sum %', np.poly1d(np.polyfit(y,x[1:], 1))(4.))

y = [0] + y
slope, intercept, r_value, s, t = stats.linregress(x,y)
print('iodine sum r2',r_value**2)

y = [Iodine[0][0],Iodine[1][0]]
a = ax3.bar([i + 0.25 * 0.4 * width for i in indeces], np.poly1d(np.polyfit(y,x[1:], 1))(4.),
        width=0.8*width, color='#A666EE')#, label='1% I')

indeces[0] = indeces[0] + 1

print('min iodine %', np.poly1d(np.polyfit(y,x[1:], 1))(4.))


x = [0,2,5]
y = [Gadolinium[0][0],Gadolinium[1][0]]
# ax3.plot(np.unique(y), np.poly1d(np.polyfit( y,x[1:], 1))(np.unique(y)),color='k',linewidth=1,label='Summed Image')
b = ax3.bar(indeces, np.poly1d(np.polyfit(y,x[1:], 1))(4.),
        color='#147A00',width= width)#, label='5% I')
print('min gad %', np.poly1d(np.polyfit(y,x[1:], 1))(4.))

y = [0] + y
slope, intercept, r_value, s, t = stats.linregress(x,y)
print('gad r2',r_value**2)

indeces[0] = indeces[0] + 1
# x = [0,1,5]
x = [0,0.4,2]

y = [Gold[0][-1],Gold[1][-1]]
# ax3.plot(np.unique(y), np.poly1d(np.polyfit( y,x[1:], 1))(np.unique(y)),color='k',linewidth=1,label='Summed Image')
d = ax3.bar(indeces, np.poly1d(np.polyfit(y,x[1:], 1))(4.), width=width,
        color='k')#, label='5% I')

y = [0] + y
slope, intercept, r_value, s, t = stats.linregress(x,y)
print('gold sum r2',r_value**2)

#print('min gold sum %', np.poly1d(np.polyfit(y,x[1:], 1))(4.))
y = [Gold[0][0],Gold[1][0]]

c = ax3.bar([i + 0.25 * 0.4 * width for i in indeces], np.poly1d(np.polyfit(y,x[1:], 1))(4.),
        color='#CB870F',width=0.8 * width)

print('min gold %', np.poly1d(np.polyfit(y,x[1:], 1))(4.))

ax3.set_xticks([1.4,2.4,3.4])
ax3.set_xticklabels(['I               ','Gd                ','Au                 '])
ax3.xaxis.set_tick_params(length=0)
ax3.set_title('d) Minimum Concentration Visible',fontsize=SIZE)
ax3.set_ylabel('% Concentration',fontsize=SIZE)
ax3.grid(True)

m2, = ax3.plot([], [], c='#A666EE' , marker='s', markersize=20,
              fillstyle='left', linestyle='none')

m3, = ax3.plot([], [], c='#147A00' , marker='s', markersize=20,
              fillstyle='bottom', linestyle='none')

m1, = ax3.plot([], [], c='#CB870F' , marker='s', markersize=20,
              fillstyle='right', linestyle='none')

#---- Plot Legend ----

ax3.legend(((m2, m1,m3), (d)), ('K-edge', 'Sum'), numpoints=1,fontsize=SIZE)
'''plt.grid(True)
plt.xticks(indices + width / 2., ["K-edge", "SEC0", "SEC1", "Sum"], size=SIZE)
plt.yticks(size=SIZE)
plt.ylabel("CNR", size=SIZE)
plt.legend(loc=0, fontsize=SIZE)
plt.ylim([0, 60])
plt.xlim([-0.5, 0.5])
plt.title("CNR of Multiplexed Spectral CT \n with Iodine Contrast - SEC")
#plt.savefig(dir_images+"CNR_multiplex_iodine_SEC.png")
plt.show()


plt.bar(indices, gd_cnr5, width=width,
        color='#147A00', label='5% Gd', yerr=gd_err5, ecolor="k")
plt.bar([i + 0.25 * 0.4 * width for i in indices], gd_cnr1,
        width=0.8 * width, color='#37D710', label='2% Gd', yerr=gd_err1, ecolor="k")
plt.axhline(4, color="r", linewidth=3, linestyle="--")
plt.grid(True)
plt.xticks(indices + width / 2., ["K-edge", "SEC2", "SEC3", "Sum"], size=SIZE)
plt.yticks(size=SIZE)
plt.ylabel("CNR", size=SIZE)
plt.legend(loc=0, fontsize=SIZE)
plt.ylim([0, 60])
plt.xlim([-0.5, 0.5])
plt.title("CNR of Multiplexed Spectral CT \n with Gadolinium Contrast - SEC")
plt.savefig(dir_images+"CNR_multiplex_gadolinium_SEC.png")
plt.show()

#Plot the gold CNR first
au_cnr1 = np.array([gold_dataK[0], gold_data4[0], gold_data5[0], gold_data6[0]])
au_err1 = np.array([gold_dataK[1], gold_data4[1], gold_data5[1], gold_data6[1]])
au_cnr5 = np.array([gold_dataK[2], gold_data4[2], gold_data5[2], gold_data6[2]])
au_err5 = np.array([gold_dataK[3], gold_data4[3], gold_data5[3], gold_data6[3]])
indices = np.arange(len(au_cnr1))
width = 0.8
plt.bar(indices, au_cnr5, width=width,
        color='#CB870F', label='5% Au', yerr=au_err5, ecolor="k")
plt.bar([i + 0.25 * 0.4 * width for i in indices], au_cnr1,
        width=0.8 * width, color='#F0E102', label='1% Au', yerr=au_err1, ecolor="k")
plt.axhline(4, color="r", linewidth=3, linestyle="--") #this is the Rose criterion
plt.grid(True)
plt.xticks(indices + width / 2., ["K-edge", "SEC4", "SEC5", "Sum"], size=SIZE)
plt.yticks(size=SIZE)
plt.ylabel("CNR", size=SIZE)
plt.legend(loc=0, fontsize=SIZE)
plt.ylim([0, 60])
plt.xlim([-0.5, 0.5])'''
plt.savefig('vision_limit.eps',dpi = 400)
plt.savefig('vision_limit.png',dpi = 400)
# Out:
# Energy bin: K-edge SEC5 - SEC4
# CNR of 1% Au vial:  4.389304472133544  +/-  2.79994120289566
# CNR of 5% Au vial:  22.373528464986645  +/-  2.377125965426498
# Energy bin: K-edge SEC3 - SEC2
# CNR of 1% Gd vial:  10.629878679879551  +/-  3.010791216216633
# CNR of 5% Gd vial:  26.45031624513559  +/-  4.233366485142992
# Energy bin: K-edge SEC1 - SEC0
# CNR of 1% I vial:  29.580327724237247  +/-  3.09487495247839
# CNR of 5% I vial:  149.39026381651342  +/-  3.283925142780701
# Energy bin: K-edge SEC5 - SEC4
# CNR of 1% Au vial:  1.6044213538225793  +/-  1.5741496655431095
# CNR of 5% Au vial:  30.478115198200097  +/-  1.4525317837534273
# Energy bin: K-edge SEC3 - SEC2
# CNR of 1% Gd vial:  15.243033995715153  +/-  1.567981039354202
# CNR of 5% Gd vial:  2.644265595793817  +/-  1.3311384148868668
# Energy bin: K-edge SEC1 - SEC0
# CNR of 1% I vial:  10.829665066877565  +/-  1.3852198571538998
# CNR of 5% I vial:  76.055468798502  +/-  2.064043607933055
# iodine r2 0.9999391320226428
# gold r2 0.9999951809086879
# min iodine sum % 0.4285714285714271
# iodine sum r2 0.9999391320226428
# min iodine % 0.14524207011686108
# min gad % 0.7547169811320739
# gad r2 0.9999999999999998
# gold sum r2 0.9999951809086877
# min gold % 0.3644444444444445

# %%
'''
After running main() method, do the K-edge subtraction
:return:
'''
slice_no = 15
m = 16

i5 = []
gd5 = []
au5 = []

i1 = []
gd1 = []
au1 = []

i0 = []
gd0 = []
au0 = []

radius = 1.593
directory = "./images"
#dir_data = "./data_no_smoothing/"

#for i in range(15,16):
i = 15

#plt.style.use('dark_background')
fig, ax = plt.subplots(nrows=3,ncols=1,figsize=(10,10), dpi=300)

ax[0] = plt.subplot(2, 2, 1)
ax[1] = plt.subplot(2, 2, 2)
ax[2] = plt.subplot(2, 2, 3)


SIZE = 8
width = 0.1
indices = [0] 


for slice_no in range(14,17):

    img0 = sio.loadmat(dir_data + "binSEC0_multiplex_corrected2.mat")['Reconimg'][:,:,slice_no]
    img1 = sio.loadmat(dir_data + "binSEC1_multiplex_corrected2.mat")['Reconimg'][:,:,slice_no]
    img2 = sio.loadmat(dir_data + "binSEC2_multiplex_corrected2.mat")['Reconimg'][:,:,slice_no]
    img3 = sio.loadmat(dir_data + "binSEC3_multiplex_corrected2.mat")['Reconimg'][:,:,slice_no]
    img4 = sio.loadmat(dir_data + "binSEC4_multiplex_corrected2.mat")['Reconimg'][:,:,slice_no]
    img5 = sio.loadmat(dir_data + "binSEC5_multiplex_corrected2.mat")['Reconimg'][:,:,slice_no]
    img6 = sio.loadmat(dir_data + "binSEC6_multiplex_corrected2.mat")['Reconimg'][:,:,slice_no]
    #import ipdb; ipdb.set_trace() 

    size = np.shape(img0)[0] #same size as all 3 here

    noise_roi = getBackgroundRegion(size)

    img_I = (img2 - img0)
    img_Gd = (img3  - img2)
    img_Au = (img5  - img4)

    noise_roi = getBackgroundRegion(size)
    air_roi = getAirRegion(size)

    number_of_noise_pixels = np.sum(noise_roi)
    number_of_air_pixels = np.sum(air_roi)

    noise_fbp_image = noise_roi * img0
    noise_air_image = air_roi * img0
    background_noise0 = np.sum(noise_fbp_image) / number_of_noise_pixels
    air_noise0 = np.sum(noise_air_image) / number_of_air_pixels
    ct_image0 = 1000 * ((img0 - background_noise0)/(background_noise0 - air_noise0))

    noise_fbp_image = noise_roi * img1
    noise_air_image = air_roi * img1
    background_noise1 = np.sum(noise_fbp_image) / number_of_noise_pixels
    air_noise1 = np.sum(noise_air_image) / number_of_air_pixels
    ct_image1 = 1000 * ((img1  - background_noise1)/(background_noise1 - air_noise1))

    noise_fbp_image = noise_roi * img2
    noise_air_image = air_roi * img2  
    background_noise2 = np.sum(noise_fbp_image) / number_of_noise_pixels
    air_noise2 = np.sum(noise_air_image) / number_of_air_pixels
    ct_image2 = 1000 * ((img2 - background_noise2)/(background_noise2 - air_noise2)) 

    noise_fbp_image = noise_roi * img3
    noise_air_image = air_roi * img3
    background_noise3 = np.sum(noise_fbp_image) / number_of_noise_pixels
    air_noise3 = np.sum(noise_air_image) / number_of_air_pixels
    ct_image3 = 1000 * ((img3 - background_noise3)/(background_noise3 - air_noise3))

    noise_fbp_image = noise_roi * img4
    noise_air_image = air_roi * img4  
    background_noise4 = np.sum(noise_fbp_image) / number_of_noise_pixels
    air_noise4 = np.sum(noise_air_image) / number_of_air_pixels
    ct_image4 = 1000 * ((img4 - background_noise4)/(background_noise4 - air_noise4))

    noise_fbp_image = noise_roi * img5
    noise_air_image = air_roi * img5  
    background_noise5 = np.sum(noise_fbp_image) / number_of_noise_pixels
    air_noise5 = np.sum(noise_air_image) / number_of_air_pixels
    ct_image5 = 1000 * ((img5 - background_noise5)/(background_noise5 - air_noise5))

    noise_fbp_image = noise_roi * img6
    noise_air_image = air_roi * img6  
    background_noise6 = np.sum(noise_fbp_image) / number_of_noise_pixels
    air_noise6 = np.sum(noise_air_image) / number_of_air_pixels
    ct_image6 = 1000 * ((img6 - background_noise6)/(background_noise6 - air_noise6))

    ct_image_I = (ct_image2 - ct_image0) #/(ct_image1 + ct_image0)
    ct_image_Gd = (ct_image3  - ct_image2) #/(ct_image3  + ct_image2)
    ct_image_Au = (ct_image5  - ct_image4) #/(ct_image5  + ct_image4)


    ct_image = np.dstack((ct_image_Gd,ct_image_Au,ct_image_I))
    that3 = np.argmax(ct_image,axis=2)
    that4 = np.argmin(ct_image,axis=2)
    difference = np.std(ct_image,axis=2) # - np.min(ct_image,axis=2)

    gold5_roi = getVialRegion("vial5Au", size)
    gold1_roi = getVialRegion("vial1Au", size)
    gadolinium5_roi = getVialRegion("vial5Gd", size)
    gadolinium1_roi = getVialRegion("vial1Gd", size)
    iodine5_roi = getVialRegion("vial5I", size)
    iodine1_roi = getVialRegion("vial1I", size)
    noise_roi = getBackgroundRegion(size)


    np_Gd = np.sum(gadolinium5_roi)
    np_Au = np.sum(gold5_roi)
    np_I = np.sum(iodine5_roi)

    np_Gd1 = np.sum(gadolinium1_roi)
    np_Au1 = np.sum(gold1_roi)
    np_I1 = np.sum(iodine1_roi)
    np_n = np.sum(noise_roi)

    av_Gd = np.sum(gadolinium5_roi*ct_image_Gd) /np_Gd 
    av_Au = np.sum(gold5_roi*ct_image_Au)       /np_Au
    av_I  = np.sum(iodine5_roi*ct_image_I)      /np_I

#     ct_image_I /= av_I
#     ct_image_Au /= av_Au
#     ct_image_Gd /= av_Gd

#     ct_image_I *= 5
#     ct_image_Au *= 2
#     ct_image_Gd *= 5

    av_Gd = np.sum(gadolinium5_roi*ct_image_Gd) /np_Gd 
    av_Au = np.sum(gold5_roi*ct_image_Au)       /np_Au
    av_I  = np.sum(iodine5_roi*ct_image_I)      /np_I    

    std_Gd = np.std(ct_image_Gd[gadolinium5_roi != 0]) 
    std_Au = np.std(ct_image_Au[gold5_roi != 0])
    std_I  = np.std(ct_image_I[iodine5_roi != 0])   

    av_Gd1 = np.sum(gadolinium1_roi*ct_image_Gd) /np_Gd1 
    av_Au1 = np.sum(gold1_roi*ct_image_Au)       /np_Au1
    av_I1  = np.sum(iodine1_roi*ct_image_I)      /np_I1    

    std_Gd1 = np.std(ct_image_Gd[gadolinium1_roi != 0]) 
    std_Au1 = np.std(ct_image_Au[gold1_roi != 0])
    std_I1  = np.std(ct_image_I[iodine1_roi != 0]) 

    av_Gd0 = np.sum(noise_roi*ct_image_Gd) /np_n 
    av_Au0 = np.sum(noise_roi*ct_image_Au) /np_n
    av_I0  = np.sum(noise_roi*ct_image_I)  /np_n

    std_Gd0 = np.std(ct_image_Gd[noise_roi != 0])
    std_I0 = np.std(ct_image_I[noise_roi != 0])
    std_Au0 = np.std(ct_image_Au[noise_roi != 0]) 
    #import ipdb; ipdb.set_trace()

    indices2 = 0 + (slice_no - 11.5)*0.03
    msize = 6
#     i5.append(av_I)
#     gd5.append(av_Gd)
#     au5.append(av_Au)

#     i1.append(av_I1)
#     gd1.append(av_Gd1)
#     au1.append(av_Au1)

#     i0.append(av_I0)
#     gd0.append(av_Gd0)
#     au0.append(av_Au0)

    cnr_gold1, err_gold1, cnr_gold5, err_gold5 = calculateCNR(ct_image_Au, gold1_roi, gold5_roi, noise_roi)
    print("Energy bin: K-edge SEC5 - SEC4")
    print("CNR of 1% Au vial: ", cnr_gold1, " +/- ", err_gold1)
    print("CNR of 5% Au vial: ", cnr_gold5, " +/- ", err_gold5)

    cnr_gadolinium1, err_gadolinium1, cnr_gadolinium5, err_gadolinium5 = calculateCNR(ct_image_Gd, gadolinium1_roi,
                                                                                  gadolinium5_roi, noise_roi)
    print( "Energy bin: K-edge SEC3 - SEC2")
    print( "CNR of 1% Gd vial: ", cnr_gadolinium1, " +/- ", err_gadolinium1)
    print( "CNR of 5% Gd vial: ", cnr_gadolinium5, " +/- ", err_gadolinium5)

    cnr_iodine1, err_iodine1, cnr_iodine5, err_iodine5 = calculateCNR(ct_image_I, iodine1_roi,
                                                                  iodine5_roi, noise_roi)
    print( "Energy bin: K-edge SEC1 - SEC0")
    print( "CNR of 1% I vial: ", cnr_iodine1, " +/- ", err_iodine1)
    print( "CNR of 5% I vial: ", cnr_iodine5, " +/- ", err_iodine5)
                                                 
    i5.append(cnr_iodine5)
    gd5.append(cnr_gadolinium5)
    au5.append(cnr_gold5)

    i1.append(cnr_iodine1)
    gd1.append(cnr_gadolinium1)
    au1.append(cnr_gold1)

    i0.append(av_I0/std_I0)
    gd0.append(av_Gd0/std_Gd0)
    au0.append(av_Au0/std_Au0)

    ax[0].scatter(5 + indices2, av_I/std_I,marker='_',color='#101010',s=msize)
    indices[0] += 1
    ax[1].scatter(5+ indices2, av_Gd/std_Gd,color='#101010',marker='_',s=msize)
    indices[0] += 1
    ax[2].scatter(5+ indices2, av_Au/std_Au,color='#101010',marker='_',s=msize)
    indices[0] += 1
    indices[0] += 1

    ax[0].scatter(1+ indices2, av_I1/std_I1, color='#101010',marker='_',s=msize)
    indices[0] += 1
    ax[1].scatter(2+ indices2, av_Gd1/std_Gd1, color='#101010',marker='_',s=msize)
    indices[0] += 1
    ax[2].scatter(1+ indices2, av_Au1/std_Au1, color='#101010',marker='_',s=msize)
    indices[0] += 1
    indices[0] += 1




arr_img = plt.imread('5%au.png', format='png')

imagebox = OffsetImage(arr_img, zoom=0.1)
imagebox.image.axes = ax[2]
offset = 1.9

ab = AnnotationBbox(imagebox, (5,0),
        xybox=(0, -7),
        xycoords=("data", "axes fraction"),
        boxcoords="offset points",
        box_alignment=(.5, offset),
        bboxprops={"edgecolor" : "k",
        "facecolor":'k'})

ax[2].add_artist(ab)

arr_img = plt.imread('1%au.png', format='png')

imagebox = OffsetImage(arr_img, zoom=0.1)
imagebox.image.axes = ax[2]

ab = AnnotationBbox(imagebox, (1,0),
        xybox=(0, -7),
        xycoords=("data", "axes fraction"),
        boxcoords="offset points",
        box_alignment=(.5, offset),
        bboxprops={"edgecolor" : "k",
        "facecolor":'k'})

ax[2].add_artist(ab)

arr_img = plt.imread('0%au.png', format='png')

imagebox = OffsetImage(arr_img, zoom=0.1)
imagebox.image.axes = ax[2]

ab = AnnotationBbox(imagebox, (0,0),
        xybox=(0, -7),
        xycoords=("data", "axes fraction"),
        boxcoords="offset points",
        box_alignment=(.5, offset),
        bboxprops={"edgecolor" : "k",
        "facecolor":'k'})

ax[2].add_artist(ab)

arr_img = plt.imread('5%i.png', format='png')

imagebox = OffsetImage(arr_img, zoom=0.1)
imagebox.image.axes = ax[0]

ab = AnnotationBbox(imagebox, (5,0),
        xybox=(0, -7),
        xycoords=("data", "axes fraction"),
        boxcoords="offset points",
        box_alignment=(.5, offset),
        bboxprops={"edgecolor" : "k",
        "facecolor":'k'})

ax[0].add_artist(ab)

arr_img = plt.imread('1%i.png', format='png')

imagebox = OffsetImage(arr_img, zoom=0.1)
imagebox.image.axes = ax[0]

ab = AnnotationBbox(imagebox, (1,0),
        xybox=(0, -7),
        xycoords=("data", "axes fraction"),
        boxcoords="offset points",
        box_alignment=(.5, offset),
        bboxprops={"edgecolor" : "k",
        "facecolor":'k'})

ax[0].add_artist(ab)

arr_img = plt.imread('0%i.png', format='png')

imagebox = OffsetImage(arr_img, zoom=0.1)
imagebox.image.axes = ax[0]

ab = AnnotationBbox(imagebox, (0,0),
        xybox=(0, -7),
        xycoords=("data", "axes fraction"),
        boxcoords="offset points",
        box_alignment=(.5, offset),
        bboxprops={"edgecolor" : "k",
        "facecolor":'k'})

ax[0].add_artist(ab)
arr_img = plt.imread('5%gd.png', format='png')

imagebox = OffsetImage(arr_img, zoom=0.1)
imagebox.image.axes = ax[1]

ab = AnnotationBbox(imagebox, (5,0),
        xybox=(0, -7),
        xycoords=("data", "axes fraction"),
        boxcoords="offset points",
        box_alignment=(.5, offset),
        bboxprops={"edgecolor" : "k",
        "facecolor":'k'})

ax[1].add_artist(ab)

arr_img = plt.imread('2%gd.png', format='png')

imagebox = OffsetImage(arr_img, zoom=0.1)
imagebox.image.axes = ax[1]

ab = AnnotationBbox(imagebox, (2,0),
        xybox=(0, -7),
        xycoords=("data", "axes fraction"),
        boxcoords="offset points",
        box_alignment=(.5, offset),
        bboxprops={"edgecolor" : "k",
        "facecolor":'k'})

ax[1].add_artist(ab)

arr_img = plt.imread('0%gd.png', format='png')

imagebox = OffsetImage(arr_img, zoom=0.1)
imagebox.image.axes = ax[1]

ab = AnnotationBbox(imagebox, (0,0),
        xybox=(0, -7),
        xycoords=("data", "axes fraction"),
        boxcoords="offset points",
        box_alignment=(.5, offset),
        bboxprops={"edgecolor" : "k",
        "facecolor":'k'})

ax[1].add_artist(ab)

ax[0].plot(5, np.mean(i5), marker='x',
  color=(1.0,0,1.0))
indices[0] += 1
ax[1].plot(5, np.mean(gd5),
  color=(0,1.0,0),marker='x',)
indices[0] += 1
ax[2].plot(5, np.mean(au5),
  color='#FFA500',marker='x',)
indices[0] += 1
indices[0] += 1

ax[0].plot(1, np.mean(i1), color=(1.0,0,1.0),marker='x')
indices[0] += 1
ax[1].plot(2, np.mean(gd1), color=(0,1.0,0),marker='x')
indices[0] += 1
ax[2].plot(1, np.mean(au1), color='#FFA500',marker='x')
indices[0] += 1
indices[0] += 1


# ax[0].plot(0, np.mean(i0),color=(1.0,0,1.0),marker='x')
# indices[0] += 1
# ax[1].plot(0, np.mean(gd0),color=(0,1.0,0),marker='x')
# indices[0] += 1
# ax[2].plot(0, np.mean(au0),color='#FFA500',marker='x')  

# import ipdb;ipdb.set_trace()
x = [0,1,5]
y = [np.mean(i1),np.mean(i5)]
ax[0].plot(np.unique(x), np.poly1d(np.polyfit(x[1:], y, 1))(np.unique(x)),'--', color=(1.0,0,1.0),linewidth=0.5,label='Linear fit')

x = [0,2,5]
y = [np.mean(gd1),np.mean(gd5)]
ax[1].plot(np.unique(x), np.poly1d(np.polyfit(x[1:], y, 1))(np.unique(x)),'--g',linewidth=0.5,label='Linear fit')

x = [0,1,5]
x2 = [0,0.4,2]
y = [np.mean(au1),np.mean(au5)]
ax[2].plot(np.unique(x), np.poly1d(np.polyfit(x[1:], y, 1))(np.unique(x)),'--', color='#FFA500',linewidth=0.5,label='Linear fit')

# x = [0,1,5]
# ax[0].plot(x, x, color='k',linewidth=0.5,label='Theoretical')

# x = [0,2,5]
# ax[1].plot(x, x, color='k',linewidth=0.5,label='Theoretical')

# x = [0,1,5]
# ax[2].plot(x, x2, color='k',linewidth=0.5,label='Theoretical')
#fig.patch.set_facecolor('k')
SIZE = 14
ax[2].set_title('c) Gold',fontsize=SIZE)
ax[0].set_title('a) Iodine',fontsize=SIZE)
ax[1].set_title('b) Gadolinium',fontsize=SIZE)

ax[2].set_ylabel('%Au',fontsize=SIZE)
ax[0].set_ylabel('%I',fontsize=SIZE)
ax[1].set_ylabel('%Gd',fontsize=SIZE)

ax[2].set_xlabel('ROI',fontsize=SIZE)
ax[0].set_xlabel('ROI',fontsize=SIZE)
ax[1].set_xlabel('            ROI',fontsize=SIZE)
ax[0].grid(True)
ax[1].grid(True)
ax[2].grid(True)
#ax[0,0].legend(loc=0, fontsize=SIZE)

ax[0].set_xticks([0,1,2,3,4,5])
ax[0].set_xticklabels(['0%','1%','','','','5%'])
ax[1].set_xticks([0,1,2,3,4,5])
ax[1].set_xticklabels(['0%','','2%','','','5%'])    
ax[2].set_xticks([0,1,2,3,4,5])
ax[2].set_xticklabels(['0%','0.4%','','','','2%'])

# ax[0].set_yticks([0,1,2,3,4,5])
# ax[1].set_yticks([0,1,2,3,4,5])   
# ax[2].set_yticks([0,0.4,0.8,1.2,1.6,2])

ax[0].legend(loc=4)
ax[1].legend(loc=4)              
ax[2].legend(loc=4)             

plt.subplots_adjust(hspace = 0.4)

fig.tight_layout()
plt.savefig('Figure7.eps',format='eps')
plt.savefig('concentrations.png')

ct_image_Au[ct_image_Au < 0] = 0
ct_image_I[ct_image_I < 0] = 0
ct_image_Gd[ct_image_Gd < 0] = 0

ct_image_Au[ct_image_Au > 5] = 5
ct_image_I[ct_image_I > 5] = 5
ct_image_Gd[ct_image_Gd > 5] = 5

im_1 = np.zeros(that3.shape)
im_2 = np.zeros(that3.shape)
im_3 = np.zeros(that3.shape)

im_1[that3 == 0] = 1
im_2[that3 == 1] = 1
im_3[that3 == 2] = 1

# %%
# For plotting CC
SIZE = 12   
#dir_data = "./data_no_smoothing/"
dir_images = "./images/"

# *******************************************************
# For plotting SEC
# load all CNR data
gold_dataK, gadolinium_dataK, iodine_dataK = np.load(dir_data + "CNRdata_Kedge_SECmultiplex_corrected2.npy")
gold_data1, gadolinium_data1, iodine_data1 = np.load(dir_data + "CNRdata_1_multiplexslice_corrected2.npy")
gold_data2, gadolinium_data2, iodine_data2 = np.load(dir_data + "CNRdata_2_multiplexslice_corrected2.npy")
gold_data3, gadolinium_data3, iodine_data3 = np.load(dir_data + "CNRdata_3_multiplexslice_corrected2.npy")
gold_data0, gadolinium_data0, iodine_data0 = np.load(dir_data + "CNRdata_0_multiplexslice_corrected2.npy")
gold_data4, gadolinium_data4, iodine_data4 = np.load(dir_data + "CNRdata_4_multiplexslice_corrected2.npy")
gold_data5, gadolinium_data5, iodine_data5 = np.load(dir_data + "CNRdata_5_multiplexslice_corrected2.npy")
gold_data6, gadolinium_data6, iodine_data6 = np.load(dir_data + "CNRdata_6_multiplexslice_corrected2.npy")

#cnr_gold1, err_gold1, cnr_gold5, err_gold5 = gold_data

fig, ax = plt.subplots(nrows=2,ncols=2,figsize=(10,5), dpi=300)

ax[0,0] = plt.subplot(1, 2, 1)
ax[0,1] = plt.subplot(2, 2, 2)
ax[1,0] = plt.subplot(2, 2, 4)

# import ipdb;ipdb.set_trace()
# and finally, plot iodine contrast
i_cnr1 = np.array([iodine_dataK[0], iodine_data0[0], iodine_data2[0], iodine_data6[0]])
i_err1 = np.array([iodine_dataK[1], iodine_data0[1], iodine_data2[1], iodine_data6[1]])
i_cnr5 = np.array([iodine_dataK[2], 42.1,66.1,42.4])
i_err5 = np.array([iodine_dataK[3], iodine_data0[3], iodine_data2[3], iodine_data6[3]])
indices = np.arange(len(i_cnr1))
width = 0.8
ax[0,0].bar(indices, i_cnr5, width=width,
        color='#4616DC', label='5% I', yerr=i_err5, ecolor="k")
ax[0,0].bar([i + 0.25 * 0.4 * width for i in indices], i_cnr1,
        width=0.8 * width, color='#A666EE', label='1% I', yerr=i_err1, ecolor="k")
ax[0,0].axhline(4, color="r", linewidth=3, linestyle="--")
ax[0,0].grid(True)
ax[0,0].xaxis.set_tick_params(length=0)    
ax[0,0].set_xticks(indices + width / 2.)
ax[0,0].set_xticklabels(["K-edge               ", "16-33 keV               ", "41-50 keV               ", "Sum               "])
#ax[0,0].set_yticks(size=SIZE)
ax[0,0].set_ylabel("CNR", size=SIZE)
ax[0,0].legend(loc=0, fontsize=SIZE)
#ax[0,0].set_ylim([0, 220])
ax[0,0].set_title("a) Iodine", size=14)
#plt.savefig(dir_images+"CNR_multiplex_iodine_SEC.png")
#ax[0,0].show()

#now plot gadolinium contrast
gd_cnr1 = np.array([gadolinium_dataK[0], 20.5, 15.4, 16.1])
gd_err1 = np.array([gadolinium_dataK[1], gadolinium_data2[1], gadolinium_data3[1], gadolinium_data6[1]])
gd_cnr5 = np.array([gadolinium_dataK[2], 7.5, 7.3, 4.6])
gd_err5 = np.array([gadolinium_dataK[3], gadolinium_data2[3], gadolinium_data3[3], gadolinium_data6[3]])

indices = np.arange(len(gd_cnr1))
width = 0.8
ax[0,1].bar(indices[0], gd_cnr5[0], width=width,
        color='#147A00', yerr=gd_err5[0], ecolor="k")
ax[0,1].bar([indices[0] + 0.25 * 0.4 * width], gd_cnr1[0],
        width=0.8 * width, color='#37D710', yerr=gd_err1[0], ecolor="k")
ax[0,1].bar(indices[1:], gd_cnr5[1:], width=width,
        color='#147A00', label='5% Gd', yerr=gd_err5[1:], ecolor="k")
ax[0,1].bar([i + 0.25 * 0.4 * width for i in indices[1:]], gd_cnr1[1:],
        width=0.8 * width, color='#37D710', label='2% Gd', yerr=gd_err1[1:], ecolor="k")
ax[0,1].axhline(4, color="r", linewidth=3, linestyle="--")
ax[0,1].grid(True)
#ax = plt.gca() 
ax[0,1].yaxis.set_ticks([10,20,30,40])  
ax[0,1].xaxis.set_tick_params(length=0)
ax[0,1].set_xticks(indices + width / 2.)
ax[0,1].set_xticklabels(["K-edge               ", "41-50 keV               ", "50-64 keV               ", "Sum               "])
#ax[0,1].set_yticks(size=SIZE)
ax[0,1].set_ylabel("CNR", size=SIZE)
ax[0,1].legend(loc=0, fontsize=SIZE)
ax[0,1].set_ylim([0, 40])
ax[0,1].set_title("b) Gadolinium", size=14)
#plt.savefig(dir_images+"CNR_multiplex_gadolinium_SEC.png")
#ax[0,1].show()

#Plot the gold CNR first
au_cnr1 = np.array([gold_dataK[0], 5.9, 5.3, 3.8])
au_err1 = np.array([gold_dataK[1], gold_data4[1], gold_data5[1], gold_data6[1]])
au_cnr5 = np.array([gold_dataK[2], 13.5,13.3,18.8])
au_err5 = np.array([gold_dataK[3], gold_data4[3], gold_data5[3], gold_data6[3]])
indices = np.arange(len(au_cnr1))
width = 0.8
ax[1,0].bar(indices, au_cnr5, width=width,
        color='#CB870F', label='2% Au', yerr=au_err5, ecolor="k")
ax[1,0].bar([i + 0.25 * 0.4 * width for i in indices], au_cnr1,
        width=0.8 * width, color='#F0E102', label='0.4% Au', yerr=au_err1, ecolor="k")
ax[1,0].axhline(4, color="r", linewidth=3, linestyle="--") #this is the Rose criterion
ax[1,0].grid(True)
#import ipdb; ipdb.set_trace()
#ax = plt.gca() 
ax[1,0].yaxis.set_ticks([10,20,30,40])
ax[1,0].xaxis.set_tick_params(length=0)
ax[1,0].set_xticks(indices + width/2.)
ax[1,0].set_xticklabels(["K-edge               ", " 64-81 keV                 ", "81-120 keV              ", "Sum               "])
ax[1,0].set_ylabel("CNR", size=SIZE)
ax[1,0].legend(loc=0, fontsize=SIZE)
ax[1,0].set_ylim([0, 40])
ax[1,0].set_title("c) Gold", size=14)
#ax[1,0].show()
fig.tight_layout()
plt.savefig("Figure6.eps",dpi=400)
