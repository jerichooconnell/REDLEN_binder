# %% [markdown]
# ## Analysis of multiplex Reconstructions
#
# Comparing the CNR in all of the methods of reconstruction as well as the qualitative signal.

# %%
# %pylab nbagg
# %load_ext autoreload
# %autoreload 2
from analyze_CBCT2 import *
dir_data = '../redlen_gui2/code_from_chelsea/run_with_quarter_time/'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Fig. 4.
#
# Each image is one axial slice of the CT reconstruction: a) The first K-edge image isolating iodine, b) the second K-edge image isolating Gadoliniumand finally c) the third K-edge image isolating Gold. Subplot d) is the summedreconstruction over all of the energy bins, the circles in the image representthe ROIs taken from the image to generate the CNR, the red circle is the ROIused to define the contrast to noise ratio.

# %%
main_Kedge_subtracted_HU(dir_data)
# Out:
# Energy bin: K-edge SEC5 - SEC4
# CNR of 0.1% Au vial:  1.4561647613062125  +/-  1.3285582212107196
# CNR of 0.5% Au vial:  9.404600763439781  +/-  1.2272664516034393
# Energy bin: K-edge SEC3 - SEC2
# CNR of 2% Gd vial:  7.7777432494869005  +/-  1.5277015266573533
# CNR of 5% Gd vial:  10.136757888647875  +/-  1.8714002581151394
# Energy bin: K-edge SEC1 - SEC0
# CNR of 1% I vial:  2.5354862693635565  +/-  1.4836568383196898
# CNR of 5% I vial:  5.380298561221513  +/-  1.986041536960899
# Energy bin:  6
# CNR of 1% Au vial:  0.7091054092434708  +/-  1.0692567820449912
# CNR of 5% Au vial:  9.700172435100907  +/-  1.0524339263616314
# Energy bin:  6
# CNR of 1% Gd vial:  4.537074790182005  +/-  1.0683775543962772
# CNR of 5% Gd vial:  1.0329056630433646  +/-  1.0367500278303892
# Energy bin:  6
# CNR of 1% I vial:  3.581782024377027  +/-  1.043597299140052
# CNR of 5% I vial:  23.89264359452369  +/-  1.1472291418149492

# %% [markdown]
# ### Fig. 5.
#
# a) Shows the CT image for reference. b) Shows reconstructed RGBusing  the  reconstruction  of  all  of  the  energy  bins  with  an  RGB  created  byassigning an gold colormap to Gold, green to Gadolinium and purple to Iodine.All  of  the  K-edge  images  are  scaled  between  0  and  5%  concentration  ofcontrast agents. c) is the composite of the two images.

# %%
plot_composite()

# %% [markdown]
# ### Fig. 6.
#
# The CNR results for the K-edge images as well as the bins used toconstruct the images for comparison. The red line denotes the limit of humanvision at a CNR value of 4.

# %%
# %pylab inline
end_plotCNR(dir_data)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Fig. 7.

# %%
main_Kedge_subtracted_HU_norm(dir_data)

# %%
import matplotlib as plt
plt.axes.text()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-294df3fb0aa2> in <module>()
#       1 import matplotlib as plt
# ----> 2 plt.axes.text()
#
# AttributeError: module 'matplotlib.axes' has no attribute 'text'

# %%
    gold_dataK, gadolinium_dataK, iodine_dataK = np.load(dir_data + "CNRdata_Kedge_SECmultiplex_corrected2.npy")
    gold_data1, gadolinium_data1, iodine_data1 = np.load(dir_data + "CNRdata_1_multiplexslice_corrected2.npy")
    gold_data2, gadolinium_data2, iodine_data2 = np.load(dir_data + "CNRdata_2_multiplexslice_corrected2.npy")
    gold_data3, gadolinium_data3, iodine_data3 = np.load(dir_data + "CNRdata_3_multiplexslice_corrected2.npy")
    gold_data0, gadolinium_data0, iodine_data0 = np.load(dir_data + "CNRdata_0_multiplexslice_corrected2.npy")
    gold_data4, gadolinium_data4, iodine_data4 = np.load(dir_data + "CNRdata_4_multiplexslice_corrected2.npy")
    gold_data5, gadolinium_data5, iodine_data5 = np.load(dir_data + "CNRdata_5_multiplexslice_corrected2.npy")
    gold_data6, gadolinium_data6, iodine_data6 = np.load(dir_data + "CNRdata_6_multiplexslice_corrected2.npy")

# %%
iodine_dataK
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-251918050bff> in <module>()
# ----> 1 iodine_dataK
#
# NameError: name 'iodine_dataK' is not defined

# %%
# %pylab nbagg
main_Kedge_subtracted_2(dir_data)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <img src="data:image/png;base64,..." width="639.3651084006071">
# <img src="data:image/png;base64,..." width="639.3651084006071">
# <img src="data:image/png;base64,..." width="639.3651084006071">
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-e90c856396fa> in <module>()
#       1 get_ipython().run_line_magic('pylab', 'nbagg')
# ----> 2 main_Kedge_subtracted_2(dir_data)
#
# /mnt/c/Users/Jericho O'Connell/Documents/REDLEN_binder/analyze_CBCT2.py in main_Kedge_subtracted_2(dir_data)
#     323     plot2DImage(img_I, extent=(-radius,radius,-radius,radius), colourmap=plt.get_cmap("Purples"), label_x="x [cm]",
#     324                 label_y="y [cm]",  saveFile=directory + "/SEC-K_I/HU/Kedge_I_CTimage_slice"+str(i), plot=True,
# --> 325                 imkwargs={"vmin": None, "vmax": None})
# ...

# %%
# %pylab inline
dir_data = './AuGdI_phantom_recons/'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def getBackgroundRegion(size):
    #grabs the water region in middle of phantom
    mask = np.zeros([size, size])
    radius = 20
    for i in range(0, size):
        for j in range(0, size):
            # first ROI
            if (i-83) ** 2 + (j-99) ** 2 < (radius ** 2): #36, 32 #near gold 5%
                mask[j][i] = 1
    return mask

def calculateCNR(img, gold1_roi, gold5_roi, noise_roi):
    '''
    I mean, this works for 1% and 5% vials of any elements really
    Helper function to calculate CNR in regions of interest
    :param img:
    :param gold1_roi:
    :param gold5_roi:
    :param noise_roi:
    :return:
    '''
    mask_gold1 = img*gold1_roi
    mask_gold5 = img*gold5_roi
    mask_background = img*noise_roi

    signal_gold1 = np.average(mask_gold1[mask_gold1 != 0])
    signal_gold5 = np.average(mask_gold5[mask_gold5 != 0])
    signal_background = np.average(mask_background[mask_background != 0])
    noise_background = np.std(mask_background[mask_background != 0])
    noise_gold1 = np.std(mask_gold1[mask_gold1 != 0])
    noise_gold5 = np.std(mask_gold5[mask_gold5 != 0])

    cnr_gold1 = np.abs(signal_gold1 - signal_background) / noise_background
    cnr_gold5 = np.abs(signal_gold5 - signal_background) / noise_background
    err_gold1 = np.sqrt(noise_gold1**2 + noise_background**2) / noise_background
    err_gold5 = np.sqrt(noise_gold5 ** 2 + noise_background ** 2) / noise_background
    return cnr_gold1, err_gold1, cnr_gold5, err_gold5

sizes = 120 #same size as all 3 here

gold5_roi = getVialRegion("vial5Au", sizes)
gold1_roi = getVialRegion("vial1Au", sizes)
gadolinium5_roi = getVialRegion("vial5Gd", sizes)
gadolinium1_roi = getVialRegion("vial1Gd", sizes)
iodine5_roi = getVialRegion("vial5I", sizes)
iodine1_roi = getVialRegion("vial1I", sizes)
noise_roi = getBackgroundRegion(sizes)

slice_no = 15
noise_roi = getBackgroundRegion(sizes)

I_1 = []
I_5 = []
G_1 = [] 
G_5 = []
A_5 = []
A_1 = []

for ii in range(0,6):
    
    img = sio.loadmat(dir_data + "binSEC"+str(ii)+"_multiplex_corrected2.mat")['Reconimg'][:,:,slice_no]
    
    cnr_iodine1, err_iodine1, cnr_iodine5, err_iodine5 = calculateCNR(img, iodine1_roi,
                                                                      iodine5_roi, noise_roi)
    print( "Contrast of 1% I vial: ", cnr_iodine1)
    print( "Contrast of 5% I vial: ", cnr_iodine5)
    
    cnr_gold1, err_gold1, cnr_gold5, err_gold5 = calculateCNR(img, gold1_roi, gold5_roi, noise_roi)
    print("Contrast of 1% Au vial: ", cnr_gold1)
    print("Contrast of 5% Au vial: ", cnr_gold5)

    cnr_gadolinium1, err_gadolinium1, cnr_gadolinium5, err_gadolinium5 = calculateCNR(img, gadolinium1_roi,
                                                                                      gadolinium5_roi, noise_roi)
    print( "Contrast of 1% Gd vial: ", cnr_gadolinium1)
    print( "Contrast of 5% Gd vial: ", cnr_gadolinium5)    
    
    I_1.append(cnr_iodine1)
    I_5.append(cnr_iodine5)
    G_1.append(cnr_gadolinium1)
    G_5.append(cnr_gadolinium5)
    A_5.append(cnr_gold1)
    A_1.append(cnr_gold5)
    
labs = ['bin0','bin1','bin2','bin3','bin4','bin5','bin0','bin1','bin2','bin3','bin4','bin5','bin0','bin1','bin2','bin3','bin4','bin5']  
tick = [0,1,2,3,4,5,10, 11, 12, 13, 14, 15,20, 21, 22, 23, 24, 25]
plt.figure()
plt.bar(range(0,6),I_5)
plt.xticks([0,1,2,3,4,5],labels=labs,rotation = 45)
plt.bar(range(0,6),I_1)
plt.bar(range(10,16),G_1)
plt.bar(range(10,16),G_5)
plt.xticks(10 + np.asarray([0,1,2,3,4,5]),labels=labs,rotation = 45)
plt.bar(range(20,26),A_1)
plt.bar(range(20,26),A_5)
plt.xticks(tick,labels=labs,rotation = 45)
plt.legend(['I5','I1','Gd1','Gd5','Au5','Au1'])
plt.title('Contrasts All')
plt.savefig('contrast_only.png')
# Out:
# Contrast of 1% I vial:  0.7329183406209123
# Contrast of 5% I vial:  3.1387999169482095
# Contrast of 1% Au vial:  0.5243352478731235
# Contrast of 5% Au vial:  2.020789591114722
# Contrast of 1% Gd vial:  0.3042189598795862
# Contrast of 5% Gd vial:  0.3642049105405168
# Contrast of 1% I vial:  0.7570243332772387
# Contrast of 5% I vial:  3.284085570871239
# Contrast of 1% Au vial:  0.48863363688428685
# Contrast of 5% Au vial:  1.9638122529930466
# Contrast of 1% Gd vial:  0.30965862727979493
# Contrast of 5% Gd vial:  0.3341077646289932
# Contrast of 1% I vial:  0.7567123713661379
# Contrast of 5% I vial:  3.59306659414481
# Contrast of 1% Au vial:  0.2781911037042126
# Contrast of 5% Au vial:  1.2742115275619965
# Contrast of 1% Gd vial:  0.30567245872923676
# Contrast of 5% Gd vial:  0.1889992422225176
# Contrast of 1% I vial:  0.73613084171512
# Contrast of 5% I vial:  3.392499274689488
# Contrast of 1% Au vial:  0.2760874840772908
# Contrast of 5% Au vial:  1.086594121488328
# ...

# %%
def calculateCNR(img, gold1_roi, gold5_roi, noise_roi):
    '''
    I mean, this works for 1% and 5% vials of any elements really
    Helper function to calculate CNR in regions of interest
    :param img:
    :param gold1_roi:
    :param gold5_roi:
    :param noise_roi:
    :return:
    '''
    mask_gold1 = img*gold1_roi
    mask_gold5 = img*gold5_roi
    mask_background = img*noise_roi

    signal_gold1 = np.average(mask_gold1[mask_gold1 != 0])
    signal_gold5 = np.average(mask_gold5[mask_gold5 != 0])
    signal_background = np.average(mask_background[mask_background != 0])
    noise_background = np.std(mask_background[mask_background != 0])
    noise_gold1 = np.std(mask_gold1[mask_gold1 != 0])
    noise_gold5 = np.std(mask_gold5[mask_gold5 != 0])

    cnr_gold1 = noise_background
    cnr_gold5 = noise_background
    err_gold1 = np.sqrt(noise_gold1**2 + noise_background**2) / noise_background
    err_gold5 = np.sqrt(noise_gold5 ** 2 + noise_background ** 2) / noise_background
    return cnr_gold1, err_gold1, cnr_gold5, err_gold5

sizes = 120 #same size as all 3 here

gold5_roi = getVialRegion("vial5Au", sizes)
gold1_roi = getVialRegion("vial1Au", sizes)
gadolinium5_roi = getVialRegion("vial5Gd", sizes)
gadolinium1_roi = getVialRegion("vial1Gd", sizes)
iodine5_roi = getVialRegion("vial5I", sizes)
iodine1_roi = getVialRegion("vial1I", sizes)
noise_roi = getBackgroundRegion(sizes)

slice_no = 15
noise_roi = getBackgroundRegion(sizes)

I_1 = []
I_5 = []
G_1 = [] 
G_5 = []
A_5 = []
A_1 = []

for ii in range(0,6):
    
    img = sio.loadmat(dir_data + "binSEC"+str(ii)+"_multiplex_corrected2.mat")['Reconimg'][:,:,slice_no]
    
    cnr_iodine1, err_iodine1, cnr_iodine5, err_iodine5 = calculateCNR(img, iodine1_roi,
                                                                      iodine5_roi, noise_roi)
    print( "CNR of 1% I vial: ", cnr_iodine1, " +/- ", err_iodine1)
    print( "CNR of 5% I vial: ", cnr_iodine5, " +/- ", err_iodine5)
    
    cnr_gold1, err_gold1, cnr_gold5, err_gold5 = calculateCNR(img, gold1_roi, gold5_roi, noise_roi)
    print("CNR of 1% Au vial: ", cnr_gold1, " +/- ", err_gold1)
    print("CNR of 5% Au vial: ", cnr_gold5, " +/- ", err_gold5)

    cnr_gadolinium1, err_gadolinium1, cnr_gadolinium5, err_gadolinium5 = calculateCNR(img, gadolinium1_roi,
                                                                                      gadolinium5_roi, noise_roi)
    print( "CNR of 1% Gd vial: ", cnr_gadolinium1, " +/- ", err_gadolinium1)
    print( "CNR of 5% Gd vial: ", cnr_gadolinium5, " +/- ", err_gadolinium5)    
    
    I_1.append(cnr_iodine1)
    I_5.append(cnr_iodine5)
    G_1.append(cnr_gadolinium1)
    G_5.append(cnr_gadolinium5)
    A_5.append(cnr_gold1)
    A_1.append(cnr_gold5)
    
labs = ['bin0','bin1','bin2','bin3','bin4','bin5','bin0','bin1','bin2','bin3','bin4','bin5','bin0','bin1','bin2','bin3','bin4','bin5']  
tick = [0,1,2,3,4,5,10, 11, 12, 13, 14, 15,20, 21, 22, 23, 24, 25]
plt.figure()
plt.bar(range(0,6),I_1)
plt.bar(range(0,6),I_5)
plt.xticks([0,1,2,3,4,5],labels=labs,rotation = 45)
plt.bar(range(10,16),G_1)
plt.bar(range(10,16),G_5)
plt.xticks(10 + np.asarray([0,1,2,3,4,5]),labels=labs,rotation = 45)
plt.bar(range(20,26),A_5)
plt.bar(range(20,26),A_1)
plt.xticks(tick,labels=labs,rotation = 45)
plt.legend(['I5','I1','Gd5','Gd1','Au5','Au1'])
plt.title('Noise All')
plt.savefig('Noise_only.png')
# Out:
# CNR of 1% I vial:  0.01965121264580885  +/-  1.000677947006307
# CNR of 5% I vial:  0.01965121264580885  +/-  1.0030729145866901
# CNR of 1% Au vial:  0.01965121264580885  +/-  1.0010517151789935
# CNR of 5% Au vial:  0.01965121264580885  +/-  1.002923748334426
# CNR of 1% Gd vial:  0.01965121264580885  +/-  1.0008599087490355
# CNR of 5% Gd vial:  0.01965121264580885  +/-  1.0005211569630137
# CNR of 1% I vial:  0.019207227909189818  +/-  1.000477856439932
# CNR of 5% I vial:  0.019207227909189818  +/-  1.0028129784432487
# CNR of 1% Au vial:  0.019207227909189818  +/-  1.000800843747289
# CNR of 5% Au vial:  0.019207227909189818  +/-  1.0022387091022973
# CNR of 1% Gd vial:  0.019207227909189818  +/-  1.0006123759084002
# CNR of 5% Gd vial:  0.019207227909189818  +/-  1.000513627366216
# CNR of 1% I vial:  0.02052026933248051  +/-  1.0003263938005387
# CNR of 5% I vial:  0.02052026933248051  +/-  1.0025605827542754
# CNR of 1% Au vial:  0.02052026933248051  +/-  1.0006142125681838
# ...

# %%
20 + np.asarray([0,1,2,3,4,5])
# Out:
# array([20, 21, 22, 23, 24, 25])

# %%
def calculateCNR(img, gold1_roi, gold5_roi, noise_roi):
    '''
    I mean, this works for 1% and 5% vials of any elements really
    Helper function to calculate CNR in regions of interest
    :param img:
    :param gold1_roi:
    :param gold5_roi:
    :param noise_roi:
    :return:
    '''
    mask_gold1 = img*gold1_roi
    mask_gold5 = img*gold5_roi
    mask_background = img*noise_roi

    signal_gold1 = np.average(mask_gold1[mask_gold1 != 0])
    signal_gold5 = np.average(mask_gold5[mask_gold5 != 0])
    signal_background = np.average(mask_background[mask_background != 0])
    noise_background = np.std(mask_background[mask_background != 0])
    noise_gold1 = np.std(mask_gold1[mask_gold1 != 0])
    noise_gold5 = np.std(mask_gold5[mask_gold5 != 0])

    cnr_gold1 = signal_gold1
    cnr_gold5 = signal_gold5
    err_gold1 = np.sqrt(noise_gold1**2 + noise_background**2) / noise_background
    err_gold5 = np.sqrt(noise_gold5 ** 2 + noise_background ** 2) / noise_background
    return cnr_gold1, err_gold1, cnr_gold5, err_gold5

sizes = 120 #same size as all 3 here

gold5_roi = getVialRegion("vial5Au", sizes)
gold1_roi = getVialRegion("vial1Au", sizes)
gadolinium5_roi = getVialRegion("vial5Gd", sizes)
gadolinium1_roi = getVialRegion("vial1Gd", sizes)
iodine5_roi = getVialRegion("vial5I", sizes)
iodine1_roi = getVialRegion("vial1I", sizes)
noise_roi = getBackgroundRegion(sizes)

slice_no = 15
noise_roi = getBackgroundRegion(sizes)

I_1 = []
I_5 = []
G_1 = [] 
G_5 = []
A_5 = []
A_1 = []

for ii in range(0,6):
    
    img = sio.loadmat(dir_data + "binSEC"+str(ii)+"_multiplex_corrected2.mat")['Reconimg'][:,:,slice_no]
    
    cnr_iodine1, err_iodine1, cnr_iodine5, err_iodine5 = calculateCNR(img, iodine1_roi,
                                                                      iodine5_roi, noise_roi)
    print( "CNR of 1% I vial: ", cnr_iodine1, " +/- ", err_iodine1)
    print( "CNR of 5% I vial: ", cnr_iodine5, " +/- ", err_iodine5)
    
    cnr_gold1, err_gold1, cnr_gold5, err_gold5 = calculateCNR(img, gold1_roi, gold5_roi, noise_roi)
    print("CNR of 1% Au vial: ", cnr_gold1, " +/- ", err_gold1)
    print("CNR of 5% Au vial: ", cnr_gold5, " +/- ", err_gold5)

    cnr_gadolinium1, err_gadolinium1, cnr_gadolinium5, err_gadolinium5 = calculateCNR(img, gadolinium1_roi,
                                                                                      gadolinium5_roi, noise_roi)
    print( "CNR of 1% Gd vial: ", cnr_gadolinium1, " +/- ", err_gadolinium1)
    print( "CNR of 5% Gd vial: ", cnr_gadolinium5, " +/- ", err_gadolinium5)    
    
    I_1.append(cnr_iodine1)
    I_5.append(cnr_iodine5)
    G_1.append(cnr_gadolinium1)
    G_5.append(cnr_gadolinium5)
    A_5.append(cnr_gold5)
    A_1.append(cnr_gold1)
    
labs = ['bin0','bin1','bin2','bin3','bin4','bin5','bin0','bin1','bin2','bin3','bin4','bin5','bin0','bin1','bin2','bin3','bin4','bin5']  
tick = [0,1,2,3,4,5,10, 11, 12, 13, 14, 15,20, 21, 22, 23, 24, 25]
plt.figure()
plt.bar(range(0,6),I_5)
plt.xticks([0,1,2,3,4,5],labels=labs,rotation = 45)
plt.bar(range(0,6),I_1)
plt.bar(range(10,16),G_5)
plt.bar(range(10,16),G_1)
plt.xticks(10 + np.asarray([0,1,2,3,4,5]),labels=labs,rotation = 45)
plt.bar(range(20,26),A_5)
plt.bar(range(20,26),A_1)
plt.xticks(tick,labels=labs,rotation = 45)
plt.legend(['I5','I1','Gd1','Gd5','Au5','Au1'])
plt.title('signal All')
plt.savefig('signal_only.png')
# Out:
# CNR of 1% I vial:  0.04431250321454015  +/-  1.0759120240757756
# CNR of 5% I vial:  0.09159099367158166  +/-  1.3096352721513247
# CNR of 1% Au vial:  0.040213592504632883  +/-  1.115577702477449
# CNR of 5% Au vial:  0.06962073501841776  +/-  1.2962943859554101
# CNR of 1% Gd vial:  0.023931497579504704  +/-  1.095400067054873
# CNR of 5% Gd vial:  0.03706683719466473  +/-  1.058835128597531
# CNR of 1% I vial:  0.042195244647305584  +/-  1.0500809366999921
# CNR of 5% I vial:  0.09073308577825283  +/-  1.2669209619961315
# CNR of 1% Au vial:  0.03704020337297999  +/-  1.082632568813496
# CNR of 5% Au vial:  0.06537429525934417  +/-  1.217136733241521
# CNR of 1% Gd vial:  0.021707221917037306  +/-  1.0637579788229863
# CNR of 5% Gd vial:  0.03407218972670621  +/-  1.0537350325742065
# CNR of 1% I vial:  0.04123445204619704  +/-  1.046384791013886
# CNR of 5% I vial:  0.09943720461993381  +/-  1.321171751462072
# CNR of 1% Au vial:  0.03141506675245433  +/-  1.0856563252439342
# ...

# %%
G_5
# Out:
# [-373.2832022338078,
#  64.52016281917177,
#  803.7368663919383,
#  955.6453591182315,
#  869.7554929535964,
#  1013.8016243770205]

# %%
plt.figure()
plt.imshow(img)
plt.colorbar()
plt.clim([-3000, 1000])
# Out:
# <img src="data:image/png;base64,..." width="639.3651084006071">
